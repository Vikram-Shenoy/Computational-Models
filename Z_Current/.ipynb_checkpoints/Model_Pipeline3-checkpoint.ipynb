# %% [markdown]
# ### Import Lib and dataset

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix , classification_report
import warnings
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')
tf.random.set_seed(1234)
import os
import random
from keras.layers import LeakyReLU

# %%
os.environ['PYTHONHASHSEED']=str(1234)
tf.random.set_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from keras import optimizers
from sklearn.metrics import confusion_matrix,accuracy_score, roc_curve, auc
from mlxtend.plotting import plot_decision_regions
# %matplotlib inline

# %%
PCA_df = pd.read_csv(r"Sets/pca_3.csv",index_col=[0])
PCA_df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.485152 -0.268583 -0.507123  0.513626 -0.233606  0.030368  0.058925
# 1    -0.145042 -0.353461 -0.183404 -0.139457 -0.245284 -0.129782  0.252421
# 2    -0.173621 -0.210423 -0.200054 -0.314970  0.105571 -0.199907 -0.110117
# 3     0.396161 -0.094074 -0.584406  0.188463  0.424859  0.632022 -0.447740
# 4    -0.427098 -0.211032  0.043938  0.211464 -0.214811 -0.171968 -0.411327
# ...        ...       ...       ...       ...       ...       ...       ...
# 1998  0.657660  0.729199 -0.639379  0.014235  0.133790 -0.012341  0.578221
# 1999 -0.326346 -0.283518 -0.013171  0.085992  0.112580  0.142915  0.355098
# 2000 -0.211847 -0.293808 -0.109366 -0.112704  0.082216 -0.011944  0.378527
# 2001 -0.334557 -0.315646 -0.028062  0.103931 -0.044717  0.070572  0.359556
# 2002 -0.255669 -0.362325 -0.069902  0.227747 -0.671268  0.428390  0.260220
#
#              7         8         9  ...        36        37        38  \
# 0    -0.343838  0.243563  0.286981  ... -0.099946  0.081991  0.090898
# 1    -0.349743  0.220273  0.805366  ...  0.155708 -0.099277  0.057628
# 2     0.278727 -0.162158  0.274271  ...  0.159069 -0.130396 -0.007525
# 3    -0.320468  0.039108 -0.089374  ...  0.037839 -0.076964  0.109443
# 4    -0.091980  0.044690 -0.117016  ... -0.249445  0.027913 -0.207839
# ...        ...       ...       ...  ...       ...       ...       ...
# 1998 -0.173464 -0.132391 -0.040307  ...  0.125742  0.031025 -0.127581
# 1999 -0.170318 -0.290209 -0.250151  ...  0.018072 -0.073200 -0.107384
# 2000  0.025612 -0.203169  0.315890  ... -0.081705 -0.005122  0.074399
# 2001 -0.061466 -0.081412  0.241167  ...  0.024980  0.011861 -0.003077
# 2002 -0.071838  0.043992  0.106095  ... -0.019813 -0.084160  0.000388
#
#             39        40        41        42        43        44        45
# 0    -0.017447  0.121411 -0.015282  0.080368 -0.118612 -0.045980 -0.011813
# 1     0.085873 -0.022387 -0.130570  0.083693  0.089900  0.141666  0.119717
# 2     0.038919 -0.133981  0.069500  0.077070  0.069247 -0.060637 -0.157007
# 3    -0.010140  0.230267  0.041187 -0.201982  0.065821 -0.019499 -0.062648
# 4     0.081620  0.099522 -0.040893  0.002526  0.224720  0.039183 -0.006331
# ...        ...       ...       ...       ...       ...       ...       ...
# 1998 -0.092240 -0.084597 -0.005976  0.010087  0.086644 -0.047780  0.064984
# 1999  0.037324  0.023242  0.009963  0.170823  0.098070  0.042203 -0.056280
# 2000 -0.203843 -0.166209 -0.082116 -0.042335  0.021290  0.068202 -0.022748
# 2001  0.053481  0.203389  0.241135 -0.139370 -0.015324 -0.123194 -0.093305
# 2002 -0.067466 -0.131197  0.134438 -0.030751  0.055404 -0.033788 -0.081546
#
# [2003 rows x 46 columns]

# %%
df = pd.read_csv(r"Sets/drug_onehot_latest.csv")
df
# Out:
#       inpatient.number  Atorvastatin calcium tablet  \
# 0               722128                            0
# 1               723327                            1
# 2               723617                            1
# 3               724385                            0
# 4               725509                            0
# ...                ...                          ...
# 1998            870258                            0
# 1999            870646                            0
# 2000            879601                            1
# 2001            905163                            0
# 2002            905720                            1
#
#       Benazepril hydrochloride tablet  Deslanoside injection  Digoxin tablet  \
# 0                                   0                      1               1
# 1                                   0                      1               1
# 2                                   0                      0               0
# 3                                   0                      1               1
# 4                                   0                      1               1
# ...                               ...                    ...             ...
# 1998                                0                      0               0
# 1999                                1                      0               0
# 2000                                1                      1               1
# 2001                                1                      1               1
# 2002                                0                      0               1
#
#       Dobutamine hydrochloride injection  Furosemide injection  \
# 0                                      0                     1
# 1                                      0                     1
# 2                                      0                     1
# 3                                      0                     1
# 4                                      0                     1
# ...                                  ...                   ...
# 1998                                   1                     1
# 1999                                   0                     1
# 2000                                   0                     1
# 2001                                   0                     1
# 2002                                   0                     1
#
#       Furosemide tablet  Hydrochlorothiazide tablet  \
# 0                     1                           0
# 1                     1                           0
# 2                     0                           0
# 3                     1                           0
# 4                     1                           0
# ...                 ...                         ...
# 1998                  1                           0
# 1999                  1                           0
# 2000                  1                           0
# 2001                  0                           0
# 2002                  1                           0
#
#       Isoprenaline Hydrochloride injection  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 1998                                     0
# 1999                                     0
# 2000                                     0
# 2001                                     0
# 2002                                     0
#
#       Isosorbide Mononitrate Sustained Release tablet  \
# 0                                                   0
# 1                                                   1
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 1998                                                0
# 1999                                                0
# 2000                                                0
# 2001                                                0
# 2002                                                0
#
#       Meglumine Adenosine Cyclophosphate for injection  Milrinone injection  \
# 0                                                    0                    1
# 1                                                    0                    1
# 2                                                    0                    0
# 3                                                    0                    1
# 4                                                    0                    1
# ...                                                ...                  ...
# 1998                                                 0                    1
# 1999                                                 0                    0
# 2000                                                 1                    1
# 2001                                                 1                    1
# 2002                                                 1                    0
#
#       Nitroglycerin injection  Shenfu injection  Spironolactone tablet  \
# 0                           0                 0                      1
# 1                           0                 0                      1
# 2                           0                 0                      1
# 3                           0                 0                      1
# 4                           0                 1                      1
# ...                       ...               ...                    ...
# 1998                        1                 0                      1
# 1999                        1                 0                      1
# 2000                        1                 0                      1
# 2001                        0                 1                      1
# 2002                        0                 0                      1
#
#       Torasemide tablet  Valsartan Dispersible tablet  \
# 0                     0                             0
# 1                     1                             1
# 2                     0                             0
# 3                     0                             0
# 4                     1                             0
# ...                 ...                           ...
# 1998                  0                             1
# 1999                  0                             0
# 2000                  0                             0
# 2001                  1                             0
# 2002                  0                             0
#
#       sulfotanshinone sodium injection
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
# ...                                ...
# 1998                                 0
# 1999                                 0
# 2000                                 0
# 2001                                 0
# 2002                                 1
#
# [2003 rows x 19 columns]

# %%
df.drop(['inpatient.number'], axis=1,inplace=True)

# %% [markdown]
# ### Create model pipeline

# %%
def model(drug, trainer):
    '''
    The model pipeline
    drug : (String) Drug name
    trainer : (DataFrame) Trainer dataset which is concatenated
    '''
    count_class_0, count_class_1 = trainer[drug].value_counts()[0], trainer[drug].value_counts()[1]

    # Divide by class
    df_class_0 = trainer[trainer[drug] == 0]
    df_class_1 = trainer[trainer[drug] == 1]
    if count_class_0>count_class_1:
        df_class_1_over = df_class_1.sample(count_class_0, replace=True)
        df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)
    else:
        df_class_0_over = df_class_0.sample(count_class_1,replace=True)
        df_test_over = pd.concat([df_class_0_over, df_class_1], axis=0)

    print('Random over-sampling:')
    print(df_test_over[drug].value_counts())
    X = df_test_over.drop(drug,axis='columns')
    y = df_test_over[drug]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)
    loss = keras.losses.BinaryCrossentropy()
    weights = -1
    
    
    reg_model = Sequential()
    reg_model.add(Dense(128, input_dim=46, activation='relu', kernel_regularizer='l2'))
    # reg_model.add(Dense(128, activation='relu'))
    # reg_model.add(Dropout(0.2))
    reg_model.add(Dropout(0.2))
    reg_model.add(Dense(64, activation='relu',kernel_regularizer='l2'))
    reg_model.add(Dropout(0.2))
    reg_model.add(Dense(32, activation='relu',  kernel_regularizer='l2'))
    reg_model.add(Dense(1, activation='sigmoid'))
    reg_model.compile(loss='binary_crossentropy', 
                    optimizer='adam', 
                    metrics=['accuracy'])


    history = reg_model.fit(X_train, y_train, 
                                validation_data=(X_test, y_test), 
                                epochs=500, verbose=0)

    # print(reg_model.evaluate(X_test, y_test))

    y_preds = reg_model.predict(X_test)
    y_preds = np.round(y_preds)
    x = classification_report(y_test, y_preds)
    # print("Classification Report: \n", )
    return [x,history]

# %%
def report_plot(drug, report, hst):
    print("For :",drug,"\nReports:\n",report)
    plt.plot(hst.history['loss'], label='train')
    plt.plot(hst.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
# for drug_name in df.columns:
#     print("Running for :",drug_name)
#     trainer = pd.concat([PCA_df, df[drug_name]], axis = 1)
#     metrics = model(drug = drug_name, trainer = trainer)
#     report, hst = metrics[0], metrics[1]
#     report_plot(drug_name,report,hst)
# Out:
# Running for : Atorvastatin calcium tablet
# Random over-sampling:
# 0    1185
# 1    1185
# Name: Atorvastatin calcium tablet, dtype: int64
# 15/15 [==============================] - 0s 874us/step - loss: 0.8227 - accuracy: 0.7553
# [0.8226909041404724, 0.75527423620224]
# For : Atorvastatin calcium tablet Reports:               precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75       237
#            1       0.75      0.77      0.76       237
#
#     accuracy                           0.76       474
#    macro avg       0.76      0.76      0.76       474
# weighted avg       0.76      0.76      0.76       474
# Running for : Benazepril hydrochloride tablet
# Random over-sampling:
# 0    1569
# 1    1569
# Name: Benazepril hydrochloride tablet, dtype: int64
# 20/20 [==============================] - 0s 943us/step - loss: 0.5479 - accuracy: 0.8599
# [0.5479064583778381, 0.8598726391792297]
# For : Benazepril hydrochloride tablet Reports:               precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85       314
#            1       0.81      0.94      0.87       314
#
#     accuracy                           0.86       628
#    macro avg       0.87      0.86      0.86       628
# weighted avg       0.87      0.86      0.86       628
# Running for : Deslanoside injection
# Random over-sampling:
# 0    1014
# 1    1014
# Name: Deslanoside injection, dtype: int64
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8400 - accuracy: 0.7611
# [0.8400446176528931, 0.761083722114563]
# For : Deslanoside injection Reports:               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       203
#            1       0.75      0.77      0.76       203
#
#     accuracy                           0.76       406
#    macro avg       0.76      0.76      0.76       406
# weighted avg       0.76      0.76      0.76       406
# Running for : Digoxin tablet
# Random over-sampling:
# 0    1006
# 1    1006
# Name: Digoxin tablet, dtype: int64
# 13/13 [==============================] - 0s 866us/step - loss: 1.1373 - accuracy: 0.6873
# [1.137256145477295, 0.6873449087142944]
# For : Digoxin tablet Reports:               precision    recall  f1-score   support
#
#            0       0.73      0.60      0.66       202
#            1       0.66      0.78      0.71       201
#
#     accuracy                           0.69       403
#    macro avg       0.69      0.69      0.68       403
# weighted avg       0.69      0.69      0.68       403
# Running for : Dobutamine hydrochloride injection
# Random over-sampling:
# 0    1981
# 1    1981
# Name: Dobutamine hydrochloride injection, dtype: int64
# 25/25 [==============================] - 0s 781us/step - loss: 0.0526 - accuracy: 0.9975
# [0.052606794983148575, 0.9974779486656189]
# For : Dobutamine hydrochloride injection Reports:               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       397
#            1       0.99      1.00      1.00       396
#
#     accuracy                           1.00       793
#    macro avg       1.00      1.00      1.00       793
# weighted avg       1.00      1.00      1.00       793
# Running for : Furosemide injection
# Random over-sampling:
# 0    1714
# 1    1714
# Name: Furosemide injection, dtype: int64
# 22/22 [==============================] - 0s 940us/step - loss: 0.3240 - accuracy: 0.9315
# [0.32400497794151306, 0.9314869046211243]
# For : Furosemide injection Reports:               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       343
#            1       0.99      0.87      0.93       343
#
#     accuracy                           0.93       686
#    macro avg       0.94      0.93      0.93       686
# weighted avg       0.94      0.93      0.93       686
# Running for : Furosemide tablet
# Random over-sampling:
# 0    1638
# 1    1638
# Name: Furosemide tablet, dtype: int64
# 21/21 [==============================] - 0s 775us/step - loss: 0.6931 - accuracy: 0.5000
# [0.6931484937667847, 0.5]
# For : Furosemide tablet Reports:               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       328
#            1       0.00      0.00      0.00       328
#
#     accuracy                           0.50       656
#    macro avg       0.25      0.50      0.33       656
# weighted avg       0.25      0.50      0.33       656
# Running for : Hydrochlorothiazide tablet
# Random over-sampling:
# 0    1722
# 1    1722
# Name: Hydrochlorothiazide tablet, dtype: int64
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3463 - accuracy: 0.9405
# [0.34629523754119873, 0.9404934644699097]
# For : Hydrochlorothiazide tablet Reports:               precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94       345
#            1       0.90      0.99      0.94       344
#
#     accuracy                           0.94       689
#    macro avg       0.95      0.94      0.94       689
# weighted avg       0.95      0.94      0.94       689
# Running for : Isoprenaline Hydrochloride injection
# Random over-sampling:
# 0    1973
# 1    1973
# Name: Isoprenaline Hydrochloride injection, dtype: int64
# 25/25 [==============================] - 0s 852us/step - loss: 0.1287 - accuracy: 0.9696
# [0.12873515486717224, 0.9696202278137207]
# For : Isoprenaline Hydrochloride injection Reports:               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97       395
#            1       0.94      1.00      0.97       395
#
#     accuracy                           0.97       790
#    macro avg       0.97      0.97      0.97       790
# weighted avg       0.97      0.97      0.97       790
# Running for : Isosorbide Mononitrate Sustained Release tablet
# Random over-sampling:
# 0    1678
# 1    1678
# Name: Isosorbide Mononitrate Sustained Release tablet, dtype: int64
# 21/21 [==============================] - 0s 863us/step - loss: 0.4091 - accuracy: 0.9122
# [0.4090818762779236, 0.9122023582458496]
# For : Isosorbide Mononitrate Sustained Release tablet Reports:               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91       336
#            1       0.86      0.98      0.92       336
#
#     accuracy                           0.91       672
#    macro avg       0.92      0.91      0.91       672
# weighted avg       0.92      0.91      0.91       672
# Running for : Meglumine Adenosine Cyclophosphate for injection
# Random over-sampling:
# 0    1110
# 1    1110
# Name: Meglumine Adenosine Cyclophosphate for injection, dtype: int64
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5000
# [0.6931471824645996, 0.5]
# For : Meglumine Adenosine Cyclophosphate for injection Reports:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       222
#            1       0.50      1.00      0.67       222
#
#     accuracy                           0.50       444
#    macro avg       0.25      0.50      0.33       444
# weighted avg       0.25      0.50      0.33       444
# Running for : Milrinone injection
# Random over-sampling:
# 0    1298
# 1    1298
# Name: Milrinone injection, dtype: int64
# 17/17 [==============================] - 0s 997us/step - loss: 0.6646 - accuracy: 0.8115
# [0.6645674705505371, 0.8115384578704834]
# For : Milrinone injection Reports:               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81       260
#            1       0.80      0.83      0.82       260
#
#     accuracy                           0.81       520
#    macro avg       0.81      0.81      0.81       520
# weighted avg       0.81      0.81      0.81       520
# Running for : Nitroglycerin injection
# Random over-sampling:
# 0    1801
# 1    1801
# Name: Nitroglycerin injection, dtype: int64
# 23/23 [==============================] - 0s 1ms/step - loss: 0.2424 - accuracy: 0.9626
# [0.2423718124628067, 0.962552011013031]
# For : Nitroglycerin injection Reports:               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       361
#            1       0.94      0.99      0.96       360
#
#     accuracy                           0.96       721
#    macro avg       0.96      0.96      0.96       721
# weighted avg       0.96      0.96      0.96       721
# Running for : Shenfu injection
# Random over-sampling:
# 0    1666
# 1    1666
# Name: Shenfu injection, dtype: int64
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3990 - accuracy: 0.9175
# [0.3990066647529602, 0.9175412058830261]
# For : Shenfu injection Reports:               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91       334
#            1       0.86      1.00      0.92       333
#
#     accuracy                           0.92       667
#    macro avg       0.93      0.92      0.92       667
# weighted avg       0.93      0.92      0.92       667
# Running for : Spironolactone tablet
# Random over-sampling:
# 0    1829
# 1    1829
# Name: Spironolactone tablet, dtype: int64
# 23/23 [==============================] - 0s 754us/step - loss: 0.1905 - accuracy: 0.9850
# [0.1905273199081421, 0.9849726557731628]
# For : Spironolactone tablet Reports:               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       366
#            1       1.00      0.97      0.98       366
#
#     accuracy                           0.98       732
#    macro avg       0.99      0.98      0.98       732
# weighted avg       0.99      0.98      0.98       732
# Running for : Torasemide tablet
# Random over-sampling:
# 0    1753
# 1    1753
# Name: Torasemide tablet, dtype: int64
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3107 - accuracy: 0.9487
# [0.31074604392051697, 0.9487179517745972]
# For : Torasemide tablet Reports:               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95       351
#            1       0.91      1.00      0.95       351
#
#     accuracy                           0.95       702
#    macro avg       0.95      0.95      0.95       702
# weighted avg       0.95      0.95      0.95       702
# Running for : Valsartan Dispersible tablet
# Random over-sampling:
# 0    1656
# 1    1656
# Name: Valsartan Dispersible tablet, dtype: int64
# 21/21 [==============================] - 0s 898us/step - loss: 0.6931 - accuracy: 0.4992
# [0.6931474208831787, 0.49924585223197937]
# For : Valsartan Dispersible tablet Reports:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       332
#            1       0.50      1.00      0.67       331
#
#     accuracy                           0.50       663
#    macro avg       0.25      0.50      0.33       663
# weighted avg       0.25      0.50      0.33       663
# Running for : sulfotanshinone sodium injection
# Random over-sampling:
# 0    1434
# 1    1434
# Name: sulfotanshinone sodium injection, dtype: int64
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5000
# [0.6931474804878235, 0.5]
# For : sulfotanshinone sodium injection Reports:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       287
#            1       0.50      1.00      0.67       287
#
#     accuracy                           0.50       574
#    macro avg       0.25      0.50      0.33       574
# weighted avg       0.25      0.50      0.33       574
