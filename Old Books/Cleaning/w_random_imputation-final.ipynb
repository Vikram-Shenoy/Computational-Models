# %%
import pandas as pd
import numpy as np 
from numpy import mean
from numpy import std
from sklearn.datasets import make_multilabel_classification
from sklearn.model_selection import RepeatedKFold
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
pd.options.display.max_rows=None
pd.options.display.max_columns=None
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(r"C:\users\vinayak\minor_proj\collabRV\Raw Sets\DATASET FOR LSTM MODEL.csv",index_col=[1])

# %%
df.head(10)
# Out:
#                   Unnamed: 0 DestinationDischarge admission.ward  \
# inpatient.number
# 857781                     1                 Home     Cardiology
# 743087                     2                 Home     Cardiology
# 866418                     3                 Home     Cardiology
# 775928                     4                 Home     Cardiology
# 810128                     5                 Home     Cardiology
# 823318                     6                 Home     Cardiology
# 844094                     7                 Home     Cardiology
# 787530                     8   HealthcareFacility     Cardiology
# 795420                     9                 Home     Cardiology
# 829801                    10                 Home     Cardiology
#
#                  admission.way     occupation discharge.department  \
# inpatient.number
# 857781            NonEmergency  UrbanResident           Cardiology
# 743087            NonEmergency  UrbanResident           Cardiology
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2008 entries, 857781 to 791864
# Columns: 166 entries, Unnamed: 0 to ageCat
# dtypes: float64(119), int64(32), object(15)
# memory usage: 2.6+ MB

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df.drop(['re.admission.time..days.from.admission.'],axis=1,inplace=True)
df.drop(['time.to.emergency.department.within.6.months'],axis=1,inplace=True)
df.head()
# Out:
#                  DestinationDischarge admission.ward admission.way  \
# inpatient.number
# 857781                           Home     Cardiology  NonEmergency
# 743087                           Home     Cardiology  NonEmergency
# 866418                           Home     Cardiology  NonEmergency
# 775928                           Home     Cardiology     Emergency
# 810128                           Home     Cardiology  NonEmergency
#
#                      occupation discharge.department  visit.times  gender  \
# inpatient.number
# 857781            UrbanResident           Cardiology            1    Male
# 743087            UrbanResident           Cardiology            1  Female
# 866418                   farmer           Cardiology            2    Male
# 775928            UrbanResident           Cardiology            1    Male
# 810128            UrbanResident           Cardiology            1  Female
#
#                   body.temperature  pulse  respiration  \
# inpatient.number
# ...

# %%
df.drop(['DestinationDischarge', 'admission.ward','admission.way','occupation','discharge.department'], axis = 1,inplace=True)
df.drop(['weight','height'],axis=1,inplace=True)
df.head()
df.drop('cholinesterase',axis=1,inplace=True)
df.drop(['time.of.death..days.from.admission.'],axis=1,inplace=True)
df.drop(df[df['outcome.during.hospitalization'] == 0].index, inplace = True)
df.drop(["death.within.6.months","death.within.28.days","death.within.3.months"],axis=1,inplace=True)
df.drop(["visit.times"],axis=1,inplace=True)
df.drop(["dischargeDay"],axis=1,inplace=True)
df.drop(["re.admission.within.28.days","re.admission.within.3.months","re.admission.within.6.months"],axis=1,inplace=True)
df.drop(["return.to.emergency.department.within.6.months"],axis=1,inplace=True)
df.drop(["outcome.during.hospitalization"],axis=1,inplace=True)

# %%
df.head()
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 857781              Male              36.7     87           19
# 743087            Female              36.8     95           18
# 866418              Male              36.5     98           18
# 775928              Male              36.0     73           19
# 810128            Female              35.0     88           19
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 857781                                102                        64
# 743087                                150                        70
# 866418                                102                        67
# 775928                                110                        74
# 810128                                134                        62
#
#                         map        BMI type.of.heart.failure  \
# inpatient.number
# ...

# %%
df.shape
# Out:
# (2008, 144)

# %%
cat_col=df.select_dtypes(include="object")

# %%
num_col=df.select_dtypes(include="number")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# set the figure size
plt.rcParams["figure.figsize"]=[15,5]

# plot a heatmap of the missing values in the data
# cbar: specify whether to display the color index or not
sns.heatmap(num_col.isnull(), cbar = False)

# display the plot
plt.show()

# %%
null_count=df.isnull().sum().sort_values(ascending=False)
percentage=((df.isnull().sum()/df.isnull().count())*100).sort_values(ascending=False)
null_df=pd.concat([null_count,percentage],axis=1,keys=["null_count","percentage"])
null_df
# Out:
#                                                     null_count  percentage
# homocysteine                                              1862   92.729084
# lipoprotein                                               1832   91.235060
# apolipoprotein.B                                          1832   91.235060
# apolipoprotein.A                                          1832   91.235060
# tricuspid.valve.return.pressure                           1826   90.936255
# erythrocyte.sedimentation.rate                            1701   84.711155
# EA                                                        1615   80.428287
# myoglobin                                                 1610   80.179283
# serum.magnesium                                           1601   79.731076
# Inorganic.Phosphorus                                      1601   79.731076
# mitral.valve.AMS                                          1458   72.609562
# ...

# %%
#although EA ratio is important, since so many nan values i decided to remove it
li = []
for column in df:
    ct = df[column].isna().sum()
    if(ct>1400):
        li.append(column)
li_new = {}

for i in li:
    ct = df[i].isna().sum()
    li_new.setdefault(i,ct)

# %%
df.drop(li,axis=1,inplace=True)
df.head()
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 857781              Male              36.7     87           19
# 743087            Female              36.8     95           18
# 866418              Male              36.5     98           18
# 775928              Male              36.0     73           19
# 810128            Female              35.0     88           19
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 857781                                102                        64
# 743087                                150                        70
# 866418                                102                        67
# 775928                                110                        74
# 810128                                134                        62
#
#                         map        BMI type.of.heart.failure  \
# inpatient.number
# ...

# %%
df.shape
# Out:
# (2008, 132)

# %%
num_col=df.select_dtypes(include="number")

# %%
cat_col=df.select_dtypes(include="object")

# %%
num_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2008 entries, 857781 to 791864
# Columns: 123 entries, body.temperature to GCS
# dtypes: float64(100), int64(23)
# memory usage: 2.0 MB

# %%
cat_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2008 entries, 857781 to 791864
# Data columns (total 9 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   gender                                2008 non-null   object
#  1   type.of.heart.failure                 2008 non-null   object
#  2   NYHA.cardiac.function.classification  2008 non-null   object
#  3   Killip.grade                          2008 non-null   object
#  4   type.II.respiratory.failure           2008 non-null   object
#  5   consciousness                         2008 non-null   object
#  6   respiratory.support.                  2008 non-null   object
#  7   oxygen.inhalation                     2008 non-null   object
#  8   ageCat                                2008 non-null   object
# dtypes: object(9)
# memory usage: 221.4+ KB

# %%
df.shape
# Out:
# (2008, 132)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# set the figure size
plt.rcParams["figure.figsize"]=[15,5]

# plot a heatmap of the missing values in the data
# cbar: specify whether to display the color index or not
sns.heatmap(num_col.isnull(), cbar = False)

# display the plot
plt.show()

# %%
#the rows with a few NaN columns, just decided to drop them, come up to 5 rows
df['CCI.score']=df['CCI.score'].dropna()
df['peptic.ulcer.disease']=df['peptic.ulcer.disease'].dropna()
df['moderate.to.severe.chronic.kidney.disease']=df['moderate.to.severe.chronic.kidney.disease'].dropna()
df['liver.disease']=df['liver.disease'].dropna()

# %%
df.dropna(subset=['CCI.score', 'peptic.ulcer.disease','moderate.to.severe.chronic.kidney.disease','liver.disease'],inplace=True)

# %%
df.shape
# Out:
# (2003, 132)

# %%
num_col1=df.select_dtypes(include="number")

# %%
num_col1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2003 entries, 857781 to 791864
# Columns: 123 entries, body.temperature to GCS
# dtypes: float64(100), int64(23)
# memory usage: 1.9 MB

# %%
# plot the boxplot for each variable
# subplots(): plot subplots
# figsize(): set the figure size
fig, ax = plt.subplots(2, 3, figsize=(15, 8))

# plot the boxplot using boxplot() from seaborn
# z: let the variable z define the boxplot
# x: data for which the boxplot is to be plotted
# orient: "h" specifies horizontal boxplot (for vertical boxplots use "v")
# whis: proportion of the IQR past the low and high quartiles to extend the plot whiskers
# ax: specifies the axes object to draw the plot o
# set_xlabel(): set the x-axis label
# fontsize: sets the font size of the x-axis label
for variable, subplot in zip(num_col1.columns, ax.flatten()):
    z = sns.boxplot(x = num_col1[variable], orient = "h",whis=1.5 , ax=subplot) # plot the boxplot
    z.set_xlabel(variable, fontsize = 20)

# %%
# z = sns.boxplot(x = num_col1[], orient = "h",whis=1.5 , ax=subplot) # plot the boxplot

# %%
for i in num_col1.columns:
    q1=num_col1[i].quantile(0.25)
    q3=num_col1[i].quantile(0.75)
    iqr=q3-q1
    ub=q3 + 1.5*iqr
    lb=q1 - 1.5*iqr
    uc=num_col1[i].quantile(0.99)
    lc=num_col1[i].quantile(0.01)
    for ind1 in num_col1[i].index:
        if num_col1.loc[ind1, i] >ub:            
            num_col1.loc[ind1, i] =uc
        if num_col1.loc[ind1, i] < lb:
            num_col1.loc[ind1, i] =lc
# Out:
# E:\anoconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# plot the boxplot for each variable
# subplots(): plot subplots
# figsize(): set the figure size
fig, ax = plt.subplots(2, 3, figsize=(15, 8))

# plot the boxplot using boxplot() from seaborn
# z: let the variable z define the boxplot
# x: data for which the boxplot is to be plotted
# orient: "h" specifies horizontal boxplot (for vertical boxplots use "v")
# whis: proportion of the IQR past the low and high quartiles to extend the plot whiskers
# ax: specifies the axes object to draw the plot o
# set_xlabel(): set the x-axis label
# fontsize: sets the font size of the x-axis label
for variable, subplot in zip(num_col1.columns, ax.flatten()):
    z = sns.boxplot(x = num_col1[variable], orient = "h",whis=1.5 , ax=subplot) # plot the boxplot
    z.set_xlabel(variable, fontsize = 20)

# %%
null_count=df.isna().sum().sort_values(ascending=False)
percentage=((df.isnull().sum()/df.isnull().count())*100).sort_values(ascending=False)
null_df=pd.concat([null_count,percentage],axis=1,keys=["null_count","percentage"])
null_df
# Out:
#                                                     null_count  percentage
# LVEF                                                      1370   68.397404
# tricuspid.valve.return.velocity                           1214   60.609086
# high.sensitivity.protein                                  1066   53.220170
# mitral.valve.EMS                                          1027   51.273090
# total.hemoglobin                                          1012   50.524214
# oxyhemoglobin                                             1012   50.524214
# carboxyhemoglobin                                         1012   50.524214
# methemoglobin                                             1012   50.524214
# hematocrit.blood.gas                                      1012   50.524214
# reduced.hemoglobin                                        1012   50.524214
# standard.residual.base                                    1011   50.474289
# ...

# %%
#drop body temperature blood gas, it is always 37
df.drop(['body.temperature.blood.gas'],axis=1,inplace=True)

# %%
# df2 =pd.read_csv(r'C:\Users\Vinayak\minor_proj\collabRV\EDA\drug_dict_onehot.csv',index_col=[0])
# df3= pd.read_csv(r"D:\git_minor\collabRV\Raw Sets\dat_md- Cardiac Dataset.csv",index_col=[1])

# %%
# df2.tail(10)

# %%
# df3.head(10)

# %%
# df3.shape

# %%
df['gender'].replace('Female',0,inplace=True)
df['gender'].replace('Male',1,inplace=True)

df['type.of.heart.failure'].replace('Left',0,inplace=True)
df['type.of.heart.failure'].replace('Right',1,inplace=True)
df['type.of.heart.failure'].replace('Both',2,inplace=True)

df['NYHA.cardiac.function.classification'].replace('III',3,inplace=True)
df['NYHA.cardiac.function.classification'].replace('II',2,inplace=True)
df['NYHA.cardiac.function.classification'].replace('IV',4,inplace=True)

df['Killip.grade'].replace('I',1,inplace=True)
df['Killip.grade'].replace('II',2,inplace=True)
df['Killip.grade'].replace('III',3,inplace=True)
df['Killip.grade'].replace('IV',4,inplace=True)

df['type.II.respiratory.failure'].replace('NonTypeII',0,inplace=True)
df['type.II.respiratory.failure'].replace('TypeII',1,inplace=True)

df['consciousness'].replace('Clear',1,inplace=True)
df['consciousness'].replace('ResponsiveToPain',2,inplace=True)
df['consciousness'].replace('ResponsiveToSound',3,inplace=True)
df['consciousness'].replace('Nonresponsive',4,inplace=True)

df['oxygen.inhalation'].replace('OxygenTherapy',0,inplace=True)
df['oxygen.inhalation'].replace('AmbientAir',1,inplace=True)

df['ageCat'].replace('(21,29]',25,inplace=True)
df['ageCat'].replace('(29,39]',35,inplace=True)
df['ageCat'].replace('(39,49]',45,inplace=True)
df['ageCat'].replace('(49,59]',55,inplace=True)
df['ageCat'].replace('(59,69]',65,inplace=True)
df['ageCat'].replace('(69,79]',75,inplace=True)
df['ageCat'].replace('(79,89]',85,inplace=True)
df['ageCat'].replace('(89,110]',100,inplace=True)

df["respiratory.support."]=df["respiratory.support."].replace("None",0)
df["respiratory.support."]=df["respiratory.support."].replace("IMV",1)
df["respiratory.support."]=df["respiratory.support."].replace("NIMV",2)

# %%
df.head()
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 857781                 1              36.7     87           19
# 743087                 0              36.8     95           18
# 866418                 1              36.5     98           18
# 775928                 1              36.0     73           19
# 810128                 0              35.0     88           19
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 857781                                102                        64
# 743087                                150                        70
# 866418                                102                        67
# 775928                                110                        74
# 810128                                134                        62
#
#                         map        BMI  type.of.heart.failure  \
# inpatient.number
# ...

# %%
df.shape
# Out:
# (2003, 131)

# %%
null_count=df.isna().sum().sort_values(ascending=False)
percentage=((df.isna().sum()/df.isna().count())*100).sort_values(ascending=False)
null_df=pd.concat([null_count,percentage],axis=1,keys=["null_count","percentage"])
null_df
# Out:
#                                                     null_count  percentage
# LVEF                                                      1370   68.397404
# tricuspid.valve.return.velocity                           1214   60.609086
# high.sensitivity.protein                                  1066   53.220170
# mitral.valve.EMS                                          1027   51.273090
# total.hemoglobin                                          1012   50.524214
# oxyhemoglobin                                             1012   50.524214
# carboxyhemoglobin                                         1012   50.524214
# methemoglobin                                             1012   50.524214
# hematocrit.blood.gas                                      1012   50.524214
# reduced.hemoglobin                                        1012   50.524214
# standard.residual.base                                    1011   50.474289
# ...

# %%
null_df.to_csv("NAN.csv")

# %%
#the discord chat ones we dicussed to drop 
df.drop(['hydroxybutyrate.dehydrogenase.to.lactate.dehydrogenase','hydroxybutyrate.dehydrogenase','free.calcium','anion.gap','lactate.dehydrogenase','lactate','CCI.score','consciousness','eye.opening','verbal.response','respiratory.support.','gender','ageCat'],axis=1,inplace=True)

# %%
df.drop(['coefficient.of.variation.of.red.blood.cell.distribution.width','standard.deviation.of.red.blood.cell.distribution.width','lymphocyte.count','basophil.ratio','basophil.count','eosinophil.ratio','eosinophil.count','platelet.distribution.width','alkaline.phosphatase','standard.residual.base','standard.bicarbonate','partial.pressure.of.carbon.dioxide','measured.residual.base','measured.bicarbonate','GCS'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (2003, 103)

# %%
variance = df.var()
columns = df.columns

# %%
variance.shape
# Out:
# (103,)

# %%
variable = [ ]
removed=[]
for i in range(0,len(variance)):
    if variance[i]>=0.006: #setting the threshold as 1%
        variable.append(columns[i])
    else:
        removed.append(columns[i])

# %%
removed
# Out:
# ['connective.tissue.disease',
#  'hemiplegia',
#  'leukemia',
#  'malignant.lymphoma',
#  'AIDS',
#  'acute.renal.failure',
#  'monocyte.ratio',
#  'hematocrit',
#  'platelet.hematocrit',
#  'pH']

# %%
df.drop(removed,inplace=True,axis=1)

# %%
# these were removed earlier because we did not find the normal range for them in the data dictionary
import random
df.drop(['tricuspid.valve.return.velocity'],axis=1,inplace=True)
df.drop(['prothrombin.time.ratio'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (2003, 91)

# %%
df.to_csv("Raw_NaN.csv")

# %%
df['high.sensitivity.protein']
# Out:
# inpatient.number
# 857781      7.6
# 743087      NaN
# 866418      NaN
# 775928      NaN
# 810128      5.9
# 823318     34.0
# 844094     46.8
# 787530      NaN
# 795420     14.3
# 829801      NaN
# 807741      NaN
# 748109      NaN
# 802296     29.5
# 744167     21.7
# 780534      3.9
# 852562      3.1
# 759947      NaN
# 825016     14.5
# 820101      NaN
# 729522      NaN
# 764082      NaN
# 765801      6.0
# 868777     10.9
# 821261      NaN
# 814869     45.8
# 818671      4.1
# 846186      NaN
# 818948      2.8
# 764380      NaN
# 861240      NaN
# 743467      NaN
# 814480      NaN
# 783621      NaN
# 766383      2.5
# 848044      NaN
# 821472      1.5
# 866373      NaN
# 793147      NaN
# 739615      NaN
# 817939      NaN
# 760822      6.1
# 831189      8.8
# 837384      NaN
# 798240     75.7
# 857297      NaN
# 727376      NaN
# 865365      7.3
# 859976      7.5
# 806646     39.4
# 862491     36.8
# 858732      NaN
# 870127      NaN
# 763014      NaN
# 814592      8.9
# ...

# %%
#the limit variable just ensures that it is filled to one row only
for i in range(2003):
    df['high.sensitivity.protein'].fillna(random.uniform(0.5,4.5),inplace=True,limit=1)

# %%
df['high.sensitivity.protein']
# Out:
# inpatient.number
# 857781      7.600000
# 743087      3.021616
# 866418      3.320745
# 775928      4.446595
# 810128      5.900000
# 823318     34.000000
# 844094     46.800000
# 787530      3.084431
# 795420     14.300000
# 829801      3.606989
# 807741      1.799340
# 748109      2.821272
# 802296     29.500000
# 744167     21.700000
# 780534      3.900000
# 852562      3.100000
# 759947      2.269791
# 825016     14.500000
# 820101      3.975585
# 729522      3.778619
# 764082      1.026442
# 765801      6.000000
# 868777     10.900000
# 821261      0.547863
# 814869     45.800000
# 818671      4.100000
# 846186      0.833375
# 818948      2.800000
# 764380      1.685071
# 861240      2.992469
# 743467      0.818460
# 814480      1.717062
# 783621      1.544024
# 766383      2.500000
# 848044      4.101427
# 821472      1.500000
# 866373      4.290342
# 793147      3.259275
# 739615      4.005687
# 817939      1.607947
# 760822      6.100000
# 831189      8.800000
# ...

# %%
# df['high.sensitivity.protein'] = df['high.sensitivity.protein'].fillna(random.uniform(0.5,4.5))

# %%
for i in range(2003):
    df['mitral.valve.EMS'] = df['mitral.valve.EMS'].fillna(random.uniform(0.65,0.75),limit=1)
    df['reduced.hemoglobin'] = df['reduced.hemoglobin'].fillna(random.uniform(0.5,4.5),limit=1)
    df['total.hemoglobin'] = df['total.hemoglobin'].fillna(random.uniform(135,170),limit=1)
    df['oxyhemoglobin'] = df['oxyhemoglobin'].fillna(random.uniform(94.5,96.5),limit=1)
    df['carboxyhemoglobin'] = df['carboxyhemoglobin'].fillna(random.uniform(0.1,1.5),limit=1)
    df['methemoglobin'] = df['methemoglobin'].fillna(random.uniform(0.5,5.5),limit=1)
    df['hematocrit.blood.gas'] = df['hematocrit.blood.gas'].fillna(random.uniform(0.,0.5),limit=1)
    df['chloride.ion'] = df['chloride.ion'].fillna(random.uniform(100,109),limit=1)
    #df['pH'] = df['pH'].fillna(random.uniform(7.36,7.44),limit=1)
    #df['standard.bicarbonate'] = df['standard.bicarbonate'].fillna(random.uniform(22,26.5),limit=1)
    #df['partial.pressure.of.carbon.dioxide'] = df['partial.pressure.of.carbon.dioxide'].fillna(random.uniform(36,44),limit=1)
    df['total.carbon.dioxide'] = df['total.carbon.dioxide'].fillna(random.uniform(25,31),limit=1)
    df['potassium.ion'] = df['potassium.ion'].fillna(random.uniform(3.6,4.4),limit=1)
    #df['standard.residual.base'] = df['standard.residual.base'].fillna(random.uniform(-2.8,2.8),limit=1)
    df['sodium.ion'] = df['sodium.ion'].fillna(random.uniform(136,146),limit=1)
    #df['free.calcium'] = df['free.calcium'].fillna(random.uniform(1.16,1.28),limit=1)
    df['glucose.blood.gas'] = df['glucose.blood.gas'].fillna(random.uniform(4,6),limit=1)
    #df['lactate'] = df['lactate'].fillna(random.uniform(0.6,2.1),limit=1)
    #df['measured.residual.base'] = df['measured.residual.base'].fillna(random.uniform(-2.8,2.8),limit=1)
    #df['measured.bicarbonate'] = df['measured.bicarbonate'].fillna(random.uniform(23,29),limit=1)
    df['oxygen.saturation'] = df['oxygen.saturation'].fillna(random.uniform(93.5,97.5),limit=1)
    df['partial.oxygen.pressure'] = df['partial.oxygen.pressure'].fillna(random.uniform(83,108),limit=1)
    #df['anion.gap'] = df['anion.gap'].fillna(random.uniform(12,16),limit=1)
    df['left.ventricular.end.diastolic.diameter.LV'] = df['left.ventricular.end.diastolic.diameter.LV'].fillna(random.uniform(3.5,5.6),limit=1)
    df['fucosidase'] = df['fucosidase'].fillna(random.uniform(0,40),limit=1)
    df['nucleotidase'] = df['nucleotidase'].fillna(random.uniform(0,10),limit=1)
    df['total.bile.acid'] = df['total.bile.acid'].fillna(random.uniform(0,20),limit=1)
    df['glutamic.oxaloacetic.transaminase'] = df['glutamic.oxaloacetic.transaminase'].fillna(random.uniform(15,40),limit=1)
    #df['hydroxybutyrate.dehydrogenase'] = df['hydroxybutyrate.dehydrogenase'].fillna(random.uniform(90,180),limit=1)
    df['creatine.kinase.isoenzyme.to.creatine.kinase'] = df['creatine.kinase.isoenzyme.to.creatine.kinase'].fillna(random.uniform(0,0.05),limit=1)
    df['creatine.kinase'] = df['creatine.kinase'].fillna(random.uniform(22,270),limit=1)
    #df['hydroxybutyrate.dehydrogenase.to.lactate.dehydrogenase'] = df['hydroxybutyrate.dehydrogenase.to.lactate.dehydrogenase'].fillna(random.uniform(0.2,0.8),limit=1)
    #df['lactate.dehydrogenase'] = df['lactate.dehydrogenase'].fillna(random.uniform(90,282),limit=1)
    df['creatine.kinase.isoenzyme'] = df['creatine.kinase.isoenzyme'].fillna(random.uniform(0,32),limit=1)
    df['cholesterol'] = df['cholesterol'].fillna(random.uniform(2.9,5.68),limit=1)
    df['low.density.lipoprotein.cholesterol'] = df['low.density.lipoprotein.cholesterol'].fillna(random.uniform(0,3.36),limit=1)
    df['triglyceride'] = df['triglyceride'].fillna(random.uniform(0.2,2.26),limit=1)
    df['high.density.lipoprotein.cholesterol'] = df['high.density.lipoprotein.cholesterol'].fillna(random.uniform(0.9,2.19),limit=1)
    df['D.dimer'] = df['D.dimer'].fillna(random.uniform(0,0.55),limit=1)
    #df['platelet.distribution.width'] = df['platelet.distribution.width'].fillna(random.uniform(9,17),limit=1)
    df['mean.platelet.volume'] = df['mean.platelet.volume'].fillna(random.uniform(6.5,12),limit=1)
    #df['platelet.hematocrit'] = df['platelet.hematocrit'].fillna(random.uniform(0.108,0.282),limit=1)
    df['glutamyltranspeptidase'] = df['glutamyltranspeptidase'].fillna(random.uniform(10,60),limit=1)
    df['albumin'] = df['albumin'].fillna(random.uniform(40,55),limit=1)
    df['indirect.bilirubin'] = df['indirect.bilirubin'].fillna(random.uniform(0,16),limit=1)
    df['white.globulin.ratio'] = df['white.globulin.ratio'].fillna(random.uniform(1.2,2.4),limit=1)
    df['glutamic.pyruvic.transaminase'] = df['glutamic.pyruvic.transaminase'].fillna(random.uniform(9,50),limit=1)
    df['total.protein'] = df['total.protein'].fillna(random.uniform(65,85),limit=1)
    df['total.bilirubin'] = df['total.bilirubin'].fillna(random.uniform(2,20.4),limit=1)
    df['direct.bilirubin'] = df['direct.bilirubin'].fillna(random.uniform(0,6.8),limit=1)
    df['globulin'] = df['globulin'].fillna(random.uniform(20,40),limit=1)
    #df['alkaline.phosphatase'] = df['alkaline.phosphatase'].fillna(random.uniform(45,125),limit=1)
    df['high.sensitivity.troponin'] = df['high.sensitivity.troponin'].fillna(random.uniform(0,14),limit=1)
    df['glomerular.filtration.rate'] = df['glomerular.filtration.rate'].fillna(random.uniform(90,120),limit=1)
    df['prothrombin.activity'] = df['prothrombin.activity'].fillna(random.uniform(70,120),limit=1)
    df['cystatin'] = df['cystatin'].fillna(random.uniform(0.51,0.98),limit=1)
    df['brain.natriuretic.peptide'] = df['brain.natriuretic.peptide'].fillna(random.uniform(0,100),limit=1)
    # df['prothrombin.time.ratio'] = df['prothrombin.time.ratio'].fillna(random.uniform())
    df['international.normalized.ratio'] = df['international.normalized.ratio'].fillna(random.uniform(0.8,1.5),limit=1)
    df['thrombin.time'] = df['thrombin.time'].fillna(random.uniform(14,21),limit=1)
    df['fibrinogen'] = df['fibrinogen'].fillna(random.uniform(2,4),limit=1)
    df['activated.partial.thromboplastin.time'] = df['activated.partial.thromboplastin.time'].fillna(random.uniform(20,40),limit=1)
#     df['standard.deviation.of.red.blood.cell.distribution.width'] = df['standard.deviation.of.red.blood.cell.distribution.width'].fillna(random.uniform(40,53))
#     df['coefficient.of.variation.of.red.blood.cell.distribution.width'] = df['coefficient.of.variation.of.red.blood.cell.distribution.width'].fillna(random.uniform(0,15))
    df['mean.hemoglobin.volume'] = df['mean.hemoglobin.volume'].fillna(random.uniform(27,35),limit=1)
    df['hemoglobin'] = df['hemoglobin'].fillna(random.uniform(110,160),limit=1)
   # df['hematocrit'] = df['hematocrit'].fillna(random.uniform(35,50),limit=1)
    df['mean.corpuscular.volume'] = df['mean.corpuscular.volume'].fillna(random.uniform(82,96),limit=1)
    df['neutrophil.ratio'] = df['neutrophil.ratio'].fillna(random.uniform(0.5,0.7),limit=1)
    df['neutrophil.count'] = df['neutrophil.count'].fillna(random.uniform(2,7),limit=1)
    #df['basophil.count'] = df['basophil.count'].fillna(random.uniform(0,0.1),limit=1)
    df['white.blood.cell'] = df['white.blood.cell'].fillna(random.uniform(4,10),limit=1)
    df['monocyte.count'] = df['monocyte.count'].fillna(random.uniform(0.2,0.8),limit=1)
    df['red.blood.cell'] = df['red.blood.cell'].fillna(random.uniform(3.5,5.5),limit=1)
    #df['lymphocyte.count'] = df['lymphocyte.count'].fillna(random.uniform(0.8,4),limit=1)
    df['mean.hemoglobin.concentration'] = df['mean.hemoglobin.concentration'].fillna(random.uniform(320,360),limit=1)
    df['platelet'] = df['platelet'].fillna(random.uniform(100,300),limit=1)
    #df['basophil.ratio'] = df['basophil.ratio'].fillna(random.uniform(0,1),limit=1)
    #df['eosinophil.ratio'] = df['eosinophil.ratio'].fillna(random.uniform(0.5,5),limit=1)
    #df['monocyte.ratio'] = df['monocyte.ratio'].fillna(random.uniform(3,11.4),limit=1)
    df['uric.acid'] = df['uric.acid'].fillna(random.uniform(150,440),limit=1)
    df['urea'] = df['urea'].fillna(random.uniform(1.7,8.3),limit=1)
    df['creatinine.enzymatic.method'] = df['creatinine.enzymatic.method'].fillna(random.uniform(44,110),limit=1)
    df['sodium'] = df['sodium'].fillna(random.uniform(137,147),limit=1)
    df['chloride'] = df['chloride'].fillna(random.uniform(99,110),limit=1)
    df['potassium'] = df['potassium'].fillna(random.uniform(3.5,4.5),limit=1)
    df['calcium'] = df['calcium'].fillna(random.uniform(2.11,2.52),limit=1)
    df['carbon.dioxide.binding.capacity'] = df['carbon.dioxide.binding.capacity'].fillna(random.uniform(22,30),limit=1)
    df['LVEF']=df['LVEF'].fillna(random.uniform(57,68),limit=1)
    #df['eosinophil.count'] = df['eosinophil.count'].fillna(random.uniform(0.02,0.5),limit=1)

# %%
df.head()
# Out:
#                   body.temperature  pulse  respiration  \
# inpatient.number
# 857781                        36.7     87           19
# 743087                        36.8     95           18
# 866418                        36.5     98           18
# 775928                        36.0     73           19
# 810128                        35.0     88           19
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 857781                                102                        64
# 743087                                150                        70
# 866418                                102                        67
# 775928                                110                        74
# 810128                                134                        62
#
#                         map        BMI  type.of.heart.failure  \
# inpatient.number
# 857781            76.666667  18.590125                      2
# ...

# %%
null_count=df.isna().sum().sort_values(ascending=False)
percentage=((df.isna().sum()/df.isna().count())*100).sort_values(ascending=False)
null_df=pd.concat([null_count,percentage],axis=1,keys=["null_count","percentage"])
null_df
# Out:
#                                               null_count  percentage
# body.temperature                                       0         0.0
# indirect.bilirubin                                     0         0.0
# glutamyltranspeptidase                                 0         0.0
# white.globulin.ratio                                   0         0.0
# albumin                                                0         0.0
# fucosidase                                             0         0.0
# nucleotidase                                           0         0.0
# high.sensitivity.protein                               0         0.0
# brain.natriuretic.peptide                              0         0.0
# creatine.kinase.isoenzyme                              0         0.0
# creatine.kinase                                        0         0.0
# glutamic.oxaloacetic.transaminase                      0         0.0
# creatine.kinase.isoenzyme.to.creatine.kinase           0         0.0
# ...

# %%
#df2 =pd.read_csv(r'C:\Users\Vinayak\minor_proj\collabRV\EDA\drug_dict_onehot.csv',index_col=[0])
df1= pd.read_csv(r"D:\Projects\collabRV\Raw Sets\dat_md- Cardiac Dataset.csv",index_col=[0])

# %%
# df1.drop(["Unnamed: 0"],axis=1,inplace=True)
# df1.head()

# %%
df1["Drug_name"].count()
# Out:
# 12654

# %%
df1["Drug_name"].unique()
# Out:
# array(['sulfotanshinone sodium injection', 'Furosemide tablet',
#        'Meglumine Adenosine Cyclophosphate for injection',
#        'Furosemide injection', 'Milrinone injection',
#        'Deslanoside injection', 'Torasemide tablet',
#        'Benazepril hydrochloride tablet', 'Atorvastatin calcium tablet',
#        'Digoxin tablet', 'Hydrochlorothiazide tablet',
#        'Spironolactone tablet', 'Valsartan Dispersible tablet',
#        'Dobutamine hydrochloride injection',
#        'Isoprenaline Hydrochloride injection', 'Nitroglycerin injection',
#        'Shenfu injection',
#        'Isosorbide Mononitrate Sustained Release tablet'], dtype=object)

# %%
df1["Drug_name"].value_counts()
# Out:
# Spironolactone tablet                               1833
# Furosemide injection                                1718
# Furosemide tablet                                   1641
# Meglumine Adenosine Cyclophosphate for injection    1114
# Deslanoside injection                               1015
# Digoxin tablet                                       998
# Atorvastatin calcium tablet                          822
# Milrinone injection                                  707
# sulfotanshinone sodium injection                     570
# Benazepril hydrochloride tablet                      434
# Valsartan Dispersible tablet                         348
# Shenfu injection                                     338
# Isosorbide Mononitrate Sustained Release tablet      326
# Hydrochlorothiazide tablet                           283
# Torasemide tablet                                    252
# Nitroglycerin injection                              203
# ...

# %%
df3 = pd.get_dummies(df1.Drug_name)
merged = pd.concat([df1,df3],axis=1)
merged.head(9)
# Out:
#    inpatient.number                                         Drug_name  \
# 1            857781                  sulfotanshinone sodium injection
# 2            857781                                 Furosemide tablet
# 3            857781  Meglumine Adenosine Cyclophosphate for injection
# 4            857781                              Furosemide injection
# 5            857781                               Milrinone injection
# 6            857781                             Deslanoside injection
# 7            857781                                 Torasemide tablet
# 8            857781                   Benazepril hydrochloride tablet
# 9            857781                       Atorvastatin calcium tablet
#
#    Atorvastatin calcium tablet  Benazepril hydrochloride tablet  \
# 1                            0                                0
# 2                            0                                0
# 3                            0                                0
# ...

# %%
merged = merged.drop(['Drug_name'],axis=1)
merged.head()
# Out:
#    inpatient.number  Atorvastatin calcium tablet  \
# 1            857781                            0
# 2            857781                            0
# 3            857781                            0
# 4            857781                            0
# 5            857781                            0
#
#    Benazepril hydrochloride tablet  Deslanoside injection  Digoxin tablet  \
# 1                                0                      0               0
# 2                                0                      0               0
# 3                                0                      0               0
# 4                                0                      0               0
# 5                                0                      0               0
#
#    Dobutamine hydrochloride injection  Furosemide injection  \
# 1                                   0                     0
# 2                                   0                     0
# ...

# %%
aggregation_function ={'inpatient.number':'first','sulfotanshinone sodium injection' :'sum','Furosemide tablet':'sum',
'Meglumine Adenosine Cyclophosphate for injection':'sum',
 'Furosemide injection':'sum',
 'Milrinone injection':'sum',
 'Deslanoside injection':'sum',
 'Torasemide tablet':'sum',
 'Benazepril hydrochloride tablet':'sum',
 'Atorvastatin calcium tablet':'sum',
 'Digoxin tablet':'sum',
 'Hydrochlorothiazide tablet':'sum',
 'Spironolactone tablet':'sum',
 'Valsartan Dispersible tablet':'sum',
 'Dobutamine hydrochloride injection':'sum',
 'Isoprenaline Hydrochloride injection':'sum',
 'Nitroglycerin injection':'sum',
 'Shenfu injection':'sum',
 'Isosorbide Mononitrate Sustained Release tablet':'sum'}
df_new = merged.groupby(merged['inpatient.number']).aggregate(aggregation_function)
#df_new = df_new.iloc[: , 1:]
df_new.head()
# Out:
#                   inpatient.number  sulfotanshinone sodium injection  \
# inpatient.number
# 722128                      722128                                 0
# 723327                      723327                                 0
# 723617                      723617                                 0
# 724385                      724385                                 0
# 725509                      725509                                 0
#
#                   Furosemide tablet  \
# inpatient.number
# 722128                            1
# 723327                            1
# 723617                            0
# 724385                            1
# 725509                            1
#
#                   Meglumine Adenosine Cyclophosphate for injection  \
# inpatient.number
# 722128                                                           0
# 723327                                                           0
# 723617                                                           0
# ...

# %%
df_new.reset_index(drop = True, inplace = True)
df_new = df_new.sort_values('inpatient.number',ascending=True)
df_new.head()
# Out:
#    inpatient.number  sulfotanshinone sodium injection  Furosemide tablet  \
# 0            722128                                 0                  1
# 1            723327                                 0                  1
# 2            723617                                 0                  0
# 3            724385                                 0                  1
# 4            725509                                 0                  1
#
#    Meglumine Adenosine Cyclophosphate for injection  Furosemide injection  \
# 0                                                 0                     1
# 1                                                 0                     1
# 2                                                 0                     1
# 3                                                 0                     1
# 4                                                 0                     1
#
#    Milrinone injection  Deslanoside injection  Torasemide tablet  \
# ...

# %%
df.head()
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 857781                 1              36.7     87           19
# 743087                 0              36.8     95           18
# 866418                 1              36.5     98           18
# 775928                 1              36.0     73           19
# 810128                 0              36.0     88           19
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 857781                                102                        64
# 743087                                150                        70
# 866418                                102                        67
# 775928                                110                        74
# 810128                                134                        62
#
#                         map        BMI  type.of.heart.failure  \
# inpatient.number
# ...

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 722128                 0              36.9     66           18
# 723327                 0              36.0     72           25
# 723617                 1              36.4     70           20
# 724385                 1              36.7    129           25
# 725509                 0              36.9    100           20
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 722128                                121                        56
# 723327                                150                        80
# 723617                                120                        80
# 724385                                122                        86
# 725509                                 95                        65
#
#                          map        BMI  type.of.heart.failure  \
# inpatient.number
# ...

# %%
df_new.set_index(['inpatient.number'],inplace=True)

# %%
df_new.sort_index(inplace=True)
df_new.head()
# Out:
#                   sulfotanshinone sodium injection  Furosemide tablet  \
# inpatient.number
# 722128                                           0                  1
# 723327                                           0                  1
# 723617                                           0                  0
# 724385                                           0                  1
# 725509                                           0                  1
#
#                   Meglumine Adenosine Cyclophosphate for injection  \
# inpatient.number
# 722128                                                           0
# 723327                                                           0
# 723617                                                           0
# 724385                                                           0
# 725509                                                           0
#
#                   Furosemide injection  Milrinone injection  \
# inpatient.number
# ...

# %%
df.reset_index(level=0,inplace=True)
df_new.reset_index(level=0,inplace=True)

# %%
len(df)
# Out:
# 2003

# %%
df3 = pd.merge(df, df_new, how='outer', suffixes=('','_y'), indicator=True)
rows_in_df_not_in_df_new = df3[df3['_merge']=='left_only'][df.columns]
rows_in_df_not_in_df_new.head()
# Out:
#       inpatient.number  gender  body.temperature  pulse  respiration  \
# 827             789308     1.0              36.5  102.0         25.0
# 955             796480     1.0              36.3   95.0         19.0
# 1503            829624     1.0              36.2   84.0         18.0
# 1890            863648     0.0              36.3   72.0         18.0
#
#       systolic.blood.pressure  diastolic.blood.pressure         map  \
# 827                     174.0                     100.0  124.666667
# 955                     150.0                      76.0  100.666667
# 1503                    122.0                      74.0   90.000000
# 1890                    110.0                      82.0   91.333333
#
#             BMI  type.of.heart.failure  NYHA.cardiac.function.classification  \
# 827   20.202020                    0.0                                   4.0
# 955   22.038567                    1.0                                   2.0
# ...

# %%
 b=[863648,796480, 789308 ,829624]
 print(b)
# Out:
# [863648, 796480, 789308, 829624]

# %%
for i in b:
    a={'inpatient.number':i,
    'Atorvastatin calcium tablet':0,
    'Benazepril hydrochloride tablet':0,
    'Deslanoside injection':0,
    'Digoxin tablet':0,
    'Dobutamine hydrochloride injection':0,
    'Furosemide injection':0,
    'Furosemide tablet':0,
    'Hydrochlorothiazide tablet':0,
    'Isoprenaline Hydrochloride injection':0,
    'Isosorbide Mononitrate Sustained Release tablet':0,
    'Meglumine Adenosine Cyclophosphate for injection':0,
    'Milrinone injection':0,
    'Nitroglycerin injection':0,
    'Shenfu injection':0,
    'Spironolactone tablet':0,
    'Torasemide tablet':0,
    'Valsartan Dispersible tablet':0,
    'sulfotanshinone sodium injection':0}
    df_new = df_new.append(a, ignore_index=True)
# Out:
# C:\Users\risha\AppData\Local\Temp\ipykernel_9500\2448987605.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(a, ignore_index=True)
# C:\Users\risha\AppData\Local\Temp\ipykernel_9500\2448987605.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(a, ignore_index=True)
# C:\Users\risha\AppData\Local\Temp\ipykernel_9500\2448987605.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(a, ignore_index=True)
# C:\Users\risha\AppData\Local\Temp\ipykernel_9500\2448987605.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df_new.shape
# Out:
# (2008, 19)

# %%
df3 = pd.merge(df_new, df, how='outer', suffixes=('','_y'), indicator=True)
rows_in_df_new_not_in_df_ = df3[df3['_merge']=='left_only'][df_new.columns]
rows_in_df_new_not_in_df_.head()
# Out:
#       inpatient.number  sulfotanshinone sodium injection  Furosemide tablet  \
# 726             782088                                 0                  0
# 873             791916                                 0                  0
# 899             793609                                 0                  1
# 917             794590                                 1                  1
# 1352            818307                                 0                  1
#
#       Meglumine Adenosine Cyclophosphate for injection  Furosemide injection  \
# 726                                                  1                     1
# 873                                                  1                     1
# 899                                                  0                     1
# 917                                                  1                     1
# 1352                                                 1                     0
#
# ...

# %%
 a=[782088,791916,793609,794590,818307]
 for i in a:
      df_new.drop(df_new[df_new['inpatient.number'] ==i ].index, inplace = True)

# %%
df_new.set_index(['inpatient.number'],inplace=True)
df_new.sort_index(inplace=True)
df_new.head()
# Out:
#                   sulfotanshinone sodium injection  Furosemide tablet  \
# inpatient.number
# 722128                                           0                  1
# 723327                                           0                  1
# 723617                                           0                  0
# 724385                                           0                  1
# 725509                                           0                  1
#
#                   Meglumine Adenosine Cyclophosphate for injection  \
# inpatient.number
# 722128                                                           0
# 723327                                                           0
# 723617                                                           0
# 724385                                                           0
# 725509                                                           0
#
#                   Furosemide injection  Milrinone injection  \
# inpatient.number
# ...

# %%
df.set_index(['inpatient.number'],inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 722128                 0              36.9     66           18
# 723327                 0              36.0     72           25
# 723617                 1              36.4     70           20
# 724385                 1              36.7    129           25
# 725509                 0              36.9    100           20
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 722128                                121                        56
# 723327                                150                        80
# 723617                                120                        80
# 724385                                122                        86
# 725509                                 95                        65
#
#                          map        BMI  type.of.heart.failure  \
# inpatient.number
# ...

# %%
df_new=df_new.sort_index(axis=1)
df_new.head()
# Out:
#                   Atorvastatin calcium tablet  \
# inpatient.number
# 722128                                      0
# 723327                                      1
# 723617                                      1
# 724385                                      0
# 725509                                      0
#
#                   Benazepril hydrochloride tablet  Deslanoside injection  \
# inpatient.number
# 722128                                          0                      1
# 723327                                          0                      1
# 723617                                          0                      0
# 724385                                          0                      1
# 725509                                          0                      1
#
#                   Digoxin tablet  Dobutamine hydrochloride injection  \
# inpatient.number
# 722128                         1                                   0
# ...

# %%
df_new.to_csv("drug_onehot_latest.csv")
df.to_csv("random_imputed.csv")
