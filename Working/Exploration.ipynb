# %%
# All the libraries you'll need( probably)
import pandas as pd
import numpy as np 
from numpy import mean
from numpy import std
from sklearn.datasets import make_multilabel_classification
from sklearn.model_selection import RepeatedKFold
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(r"D:\git_minor\collabRV\EDA\Optimizable(nan).csv",index_col=[0])

# %%
df.head()
# Out:
#    gender  body.temperature     pulse  respiration  systolic.blood.pressure  \
# 0     0.0          0.271429  0.333333     0.500000                 0.480159
# 1     0.0          0.142857  0.363636     0.583333                 0.595238
# 2     1.0          0.200000  0.353535     0.555556                 0.476190
# 3     1.0          0.242857  0.651515     0.611111                 0.484127
# 4     0.0          0.271429  0.505051     0.555556                 0.376984
#
#    diastolic.blood.pressure       map       BMI  type.of.heart.failure  \
# 0                  0.383562  0.428309  0.046006                    1.0
# 1                  0.547945  0.569853  0.053564                    1.0
# 2                  0.547945  0.514706  0.076992                    1.0
# 3                  0.589041  0.540441  0.049828                    1.0
# 4                  0.445205  0.413603  0.054523                    1.0
#
#    NYHA.cardiac.function.classification  ...  measured.bicarbonate  \
# ...

# %%
li = []
for column in df:
    ct = df[column].isna().sum()
    if(ct>1300):
        li.append(column)
li_new = {}

for i in li:
    ct = df[i].isna().sum()
    li_new.setdefault(i,ct)

# %%
li_new
# Out:
# {'LVEF': 1364,
#  'mitral.valve.AMS': 1451,
#  'EA': 1606,
#  'tricuspid.valve.return.pressure': 1817,
#  'myoglobin': 1599,
#  'Inorganic.Phosphorus': 1592,
#  'serum.magnesium': 1592,
#  'glutamic.oxaliplatin': 1410,
#  'erythrocyte.sedimentation.rate': 1691,
#  'homocysteine': 1851,
#  'apolipoprotein.A': 1821,
#  'apolipoprotein.B': 1821,
#  'lipoprotein': 1821}

# %%
df.drop(li,axis=1,inplace= True)

# %%
df.head()
# Out:
#    gender  body.temperature     pulse  respiration  systolic.blood.pressure  \
# 0     0.0          0.271429  0.333333     0.500000                 0.480159
# 1     0.0          0.142857  0.363636     0.583333                 0.595238
# 2     1.0          0.200000  0.353535     0.555556                 0.476190
# 3     1.0          0.242857  0.651515     0.611111                 0.484127
# 4     0.0          0.271429  0.505051     0.555556                 0.376984
#
#    diastolic.blood.pressure       map       BMI  type.of.heart.failure  \
# 0                  0.383562  0.428309  0.046006                    1.0
# 1                  0.547945  0.569853  0.053564                    1.0
# 2                  0.547945  0.514706  0.076992                    1.0
# 3                  0.589041  0.540441  0.049828                    1.0
# 4                  0.445205  0.413603  0.054523                    1.0
#
#    NYHA.cardiac.function.classification  ...  measured.bicarbonate  \
# ...

# %%
df.corr()
# Out:
#                            gender  body.temperature     pulse  respiration  \
# gender                   1.000000         -0.041915 -0.049521    -0.018300
# body.temperature        -0.041915          1.000000  0.093720     0.018016
# pulse                   -0.049521          0.093720  1.000000     0.332740
# respiration             -0.018300          0.018016  0.332740     1.000000
# systolic.blood.pressure -0.035088          0.049587  0.089887     0.103982
# ...                           ...               ...       ...          ...
# anion.gap                0.029161         -0.024557  0.178234     0.191950
# free.calcium            -0.000740         -0.076453  0.000267    -0.062849
# total.hemoglobin         0.220496         -0.110303  0.080011     0.060615
# GCS                     -0.011064          0.029867 -0.046082    -0.116088
# ageCat                  -0.124671         -0.001835 -0.085796     0.013161
#
# ...

# %%
x=df.corr().round(7)
x=x.abs()

# %%
s = x.unstack()
so = s.sort_values(kind="quicksort",ascending=False)

# %%
a = so[131:220:2]

# %%
a
# Out:
# total.carbon.dioxide                 measured.bicarbonate               0.999212
# oxygen.saturation                    reduced.hemoglobin                 0.998888
# prothrombin.time.ratio               international.normalized.ratio     0.997029
# standard.bicarbonate                 measured.residual.base             0.996527
# reduced.hemoglobin                   oxyhemoglobin                      0.995091
# oxyhemoglobin                        oxygen.saturation                  0.994604
# measured.residual.base               standard.residual.base             0.992542
# standard.bicarbonate                 standard.residual.base             0.991461
# hemoglobin                           hematocrit                         0.985292
# measured.bicarbonate                 standard.residual.base             0.976541
# neutrophil.count                     white.blood.cell                   0.975331
# total.carbon.dioxide                 standard.residual.base             0.968054
# ...

# %%
##a.to_csv("Correlated.csv")

# %%
a =  pd.read_csv(r"C:\Users\Vikram\Desktop\Minor project\Working\Correlated.csv",index_col=[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-9aadafaecfb1> in <module>
# ----> 1 a =  pd.read_csv(r"C:\Users\Vikram\Desktop\Minor project\Working\Correlated.csv",index_col=[0])
#
# E:\anoconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
a
# Out:
# total.carbon.dioxide                 measured.bicarbonate               0.999212
# oxygen.saturation                    reduced.hemoglobin                 0.998888
# prothrombin.time.ratio               international.normalized.ratio     0.997029
# standard.bicarbonate                 measured.residual.base             0.996527
# reduced.hemoglobin                   oxyhemoglobin                      0.995091
# oxyhemoglobin                        oxygen.saturation                  0.994604
# measured.residual.base               standard.residual.base             0.992542
# standard.bicarbonate                 standard.residual.base             0.991461
# hemoglobin                           hematocrit                         0.985292
# measured.bicarbonate                 standard.residual.base             0.976541
# neutrophil.count                     white.blood.cell                   0.975331
# total.carbon.dioxide                 standard.residual.base             0.968054
# ...

# %%
# we delete columns with high correalation to reduce complexity of our data

# %%
df.drop(['total.carbon.dioxide','reduced.hemoglobin','international.normalized.ratio','standard.bicarbonate','oxyhemoglobin','measured.residual.base','standard.bicarbonate','hematocrit','measured.bicarbonate','neutrophil.count','total.carbon.dioxide','hematocrit.blood.gas','platelet.hematocrit','mean.corpuscular.volume','verbal.response','low.density.lipoprotein.cholesterol','direct.bilirubin','movement','indirect.bilirubin','systolic.blood.pressure','total.hemoglobin','eosinophil.ratio','hydroxybutyrate.dehydrogenase','verbal.response','GCS','chloride','systolic.blood.pressure','red.blood.cell','sodium.ion','glutamic.oxaloacetic.transaminase','glutamic.oxaloacetic.transaminase','hematocrit.blood.gas','potassium.ion','consciousness','carbon.dioxide.binding.capacity','carbon.dioxide.binding.capacity','basophil.count'],axis=1,inplace=True)

# %%
df.drop(['diastolic.blood.pressure'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender  body.temperature     pulse  respiration       map       BMI  \
# 0     0.0          0.271429  0.333333     0.500000  0.428309  0.046006
# 1     0.0          0.142857  0.363636     0.583333  0.569853  0.053564
# 2     1.0          0.200000  0.353535     0.555556  0.514706  0.076992
# 3     1.0          0.242857  0.651515     0.611111  0.540441  0.049828
# 4     0.0          0.271429  0.505051     0.555556  0.413603  0.054523
#
#    type.of.heart.failure  NYHA.cardiac.function.classification  Killip.grade  \
# 0                    1.0                                   1.0      0.000000
# 1                    1.0                                   1.0      0.000000
# 2                    1.0                                   0.5      0.333333
# 3                    1.0                                   0.5      0.666667
# 4                    1.0                                   0.5      0.000000
#
# ...

# %%
df.to_csv("reduced_col.csv")
