# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("random_imputed.csv",index_col=[0])
df1.sample(5)
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 784471                 0              37.2     58           18
# 780515                 0              36.5     71           18
# 829800                 1              36.0     92           21
# 736827                 0              36.5    112           18
# 812145                 0              36.7     96           20
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 784471                                120                        58
# 780515                                122                        78
# 829800                                140                       100
# 736827                                134                        70
# 812145                                160                        70
#
#                          map        BMI  type.of.heart.failure  \
# inpatient.number
# 784471             78.666667  20.408163                      2
# 780515             92.666667  19.562955                      2
# 829800            113.333333  17.928215                      2
# 736827             91.333333  26.666667                      1
# 812145            100.000000  20.811655                      2
#
#                   NYHA.cardiac.function.classification  ...  \
# inpatient.number                                        ...
# 784471                                               2  ...
# 780515                                               4  ...
# 829800                                               4  ...
# 736827                                               3  ...
# 812145                                               3  ...
#
#                   measured.bicarbonate  carboxyhemoglobin  oxygen.saturation  \
# inpatient.number
# 784471                       23.246503           1.217008          96.585423
# 780515                       23.246503           1.217008          96.585423
# 829800                       18.900000           0.800000          98.000000
# 736827                       23.246503           1.217008          96.585423
# 812145                       26.800000           0.900000          97.000000
#
#                   partial.oxygen.pressure  oxyhemoglobin  anion.gap  \
# inpatient.number
# 784471                           86.74564      94.749285  15.874385
# 780515                           86.74564      94.749285  15.874385
# 829800                          120.00000      97.200000  15.500000
# 736827                           86.74564      94.749285  15.874385
# 812145                           91.00000      95.600000  11.700000
#
#                   free.calcium  total.hemoglobin  GCS  ageCat
# inpatient.number
# 784471                1.252327        151.929679   15      75
# 780515                1.252327        151.929679   15      75
# 829800                1.100000        139.000000   15      85
# 736827                1.252327        151.929679   15      75
# 812145                1.120000        108.000000   15      75
#
# [5 rows x 128 columns]

# %%
df3=pd.read_csv("drug_onehot_latest.csv",index_col=[0])
df3.head()
# Out:
#                   sulfotanshinone sodium injection  Furosemide tablet  \
# inpatient.number
# 722128                                           0                  1
# 723327                                           0                  1
# 723617                                           0                  0
# 724385                                           0                  1
# 725509                                           0                  1
#
#                   Meglumine Adenosine Cyclophosphate for injection  \
# inpatient.number
# 722128                                                           0
# 723327                                                           0
# 723617                                                           0
# 724385                                                           0
# 725509                                                           0
#
#                   Furosemide injection  Milrinone injection  \
# inpatient.number
# 722128                               1                    1
# 723327                               1                    1
# 723617                               1                    0
# 724385                               1                    1
# 725509                               1                    1
#
#                   Deslanoside injection  Torasemide tablet  \
# inpatient.number
# 722128                                1                  0
# 723327                                1                  1
# 723617                                0                  0
# 724385                                1                  0
# 725509                                1                  1
#
#                   Benazepril hydrochloride tablet  \
# inpatient.number
# 722128                                          0
# 723327                                          0
# 723617                                          0
# 724385                                          0
# 725509                                          0
#
#                   Atorvastatin calcium tablet  Digoxin tablet  \
# inpatient.number
# 722128                                      0               1
# 723327                                      1               1
# 723617                                      1               0
# 724385                                      0               1
# 725509                                      0               1
#
#                   Hydrochlorothiazide tablet  Spironolactone tablet  \
# inpatient.number
# 722128                                     0                      1
# 723327                                     0                      1
# 723617                                     0                      1
# 724385                                     0                      1
# 725509                                     0                      1
#
#                   Valsartan Dispersible tablet  \
# inpatient.number
# 722128                                       0
# 723327                                       1
# 723617                                       0
# 724385                                       0
# 725509                                       0
#
#                   Dobutamine hydrochloride injection  \
# inpatient.number
# 722128                                             0
# 723327                                             0
# 723617                                             0
# 724385                                             0
# 725509                                             0
#
#                   Isoprenaline Hydrochloride injection  \
# inpatient.number
# 722128                                               0
# 723327                                               0
# 723617                                               0
# 724385                                               0
# 725509                                               0
#
#                   Nitroglycerin injection  Shenfu injection  \
# inpatient.number
# 722128                                  0                 0
# 723327                                  0                 0
# 723617                                  0                 0
# 724385                                  0                 0
# 725509                                  0                 1
#
#                   Isosorbide Mononitrate Sustained Release tablet
# inpatient.number
# 722128                                                          0
# 723327                                                          1
# 723617                                                          0
# 724385                                                          0
# 725509                                                          0

# %%
for q in df3.columns:
    print(df3[q].value_counts())
# Out:
# 0    1185
# 1     818
# Name: Atorvastatin calcium tablet, dtype: int64
# 0    1569
# 1     434
# Name: Benazepril hydrochloride tablet, dtype: int64
# 1    1014
# 0     989
# Name: Deslanoside injection, dtype: int64
# 0    1006
# 1     997
# Name: Digoxin tablet, dtype: int64
# 0    1981
# 1      22
# Name: Dobutamine hydrochloride injection, dtype: int64
# 1    1714
# 0     289
# Name: Furosemide injection, dtype: int64
# 1    1638
# 0     365
# Name: Furosemide tablet, dtype: int64
# 0    1722
# 1     281
# Name: Hydrochlorothiazide tablet, dtype: int64
# 0    1973
# 1      30
# Name: Isoprenaline Hydrochloride injection, dtype: int64
# 0    1678
# 1     325
# Name: Isosorbide Mononitrate Sustained Release tablet, dtype: int64
# 1    1110
# 0     893
# Name: Meglumine Adenosine Cyclophosphate for injection, dtype: int64
# 0    1298
# 1     705
# Name: Milrinone injection, dtype: int64
# 0    1801
# 1     202
# Name: Nitroglycerin injection, dtype: int64
# 0    1666
# 1     337
# Name: Shenfu injection, dtype: int64
# 1    1829
# 0     174
# Name: Spironolactone tablet, dtype: int64
# 0    1753
# 1     250
# Name: Torasemide tablet, dtype: int64
# 0    1656
# 1     347
# Name: Valsartan Dispersible tablet, dtype: int64
# 0    1434
# 1     569
# Name: sulfotanshinone sodium injection, dtype: int64

# %%
df2=df3['Spironolactone tablet']
df2 = df2.to_frame()

# %%
df2.head()
# Out:
#                   Spironolactone tablet
# inpatient.number
# 722128                                1
# 723327                                1
# 723617                                1
# 724385                                1
# 725509                                1

# %%
df=pd.concat([df1,df2],axis=1)

# %%
df.head()
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 722128                 0              36.9     66           18
# 723327                 0              36.0     72           21
# 723617                 1              36.4     70           20
# 724385                 1              36.7    129           22
# 725509                 0              36.9    100           20
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 722128                                121                        56
# 723327                                150                        80
# 723617                                120                        80
# 724385                                122                        86
# 725509                                 95                        65
#
#                          map        BMI  type.of.heart.failure  \
# inpatient.number
# 722128             77.666667  18.590125                      2
# 723327            103.333333  21.644121                      2
# 723617             93.333333  31.111111                      2
# 724385             98.000000  20.134780                      2
# 725509             75.000000  22.031726                      2
#
#                   NYHA.cardiac.function.classification  ...  \
# inpatient.number                                        ...
# 722128                                               4  ...
# 723327                                               4  ...
# 723617                                               3  ...
# 724385                                               3  ...
# 725509                                               3  ...
#
#                   carboxyhemoglobin  oxygen.saturation  \
# inpatient.number
# 722128                     1.217008          96.585423
# 723327                     0.700000          91.000000
# 723617                     0.000000          98.000000
# 724385                     1.217008          96.585423
# 725509                     1.217008          96.585423
#
#                   partial.oxygen.pressure  oxyhemoglobin  anion.gap  \
# inpatient.number
# 722128                           86.74564      94.749285  15.874385
# 723327                           64.00000      90.000000  13.000000
# 723617                          106.00000      97.700000   9.100000
# 724385                           86.74564      94.749285  15.874385
# 725509                           86.74564      94.749285  15.874385
#
#                   free.calcium  total.hemoglobin  GCS  ageCat  \
# inpatient.number
# 722128                1.252327        151.929679   15      75
# 723327                1.110000         73.000000   15      65
# 723617                1.110000        104.000000   15      85
# 724385                1.252327        151.929679   15      75
# 725509                1.252327        151.929679   15      45
#
#                   Spironolactone tablet
# inpatient.number
# 722128                                1
# 723327                                1
# 723617                                1
# 724385                                1
# 725509                                1
#
# [5 rows x 129 columns]

# %%
cols_to_scale = [df.columns]

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_df= scaler.fit_transform(df)

# %%
df = pd.DataFrame(scaled_df,columns = df.columns)

# %%
df.head()
# Out:
#    gender  body.temperature     pulse  respiration  systolic.blood.pressure  \
# 0     0.0          0.271429  0.333333     0.500000                 0.480159
# 1     0.0          0.142857  0.363636     0.583333                 0.595238
# 2     1.0          0.200000  0.353535     0.555556                 0.476190
# 3     1.0          0.242857  0.651515     0.611111                 0.484127
# 4     0.0          0.271429  0.505051     0.555556                 0.376984
#
#    diastolic.blood.pressure       map       BMI  type.of.heart.failure  \
# 0                  0.383562  0.428309  0.046006                    1.0
# 1                  0.547945  0.569853  0.053564                    1.0
# 2                  0.547945  0.514706  0.076992                    1.0
# 3                  0.589041  0.540441  0.049828                    1.0
# 4                  0.445205  0.413603  0.054523                    1.0
#
#    NYHA.cardiac.function.classification  ...  carboxyhemoglobin  \
# 0                                   1.0  ...           0.229624
# 1                                   1.0  ...           0.132075
# 2                                   0.5  ...           0.000000
# 3                                   0.5  ...           0.229624
# 4                                   0.5  ...           0.229624
#
#    oxygen.saturation  partial.oxygen.pressure  oxyhemoglobin  anion.gap  \
# 0           0.954472                 0.284024       0.941835   0.380276
# 1           0.880000                 0.187234       0.878342   0.316258
# 2           0.973333                 0.365957       0.981283   0.229399
# 3           0.954472                 0.284024       0.941835   0.380276
# 4           0.954472                 0.284024       0.941835   0.380276
#
#    free.calcium  total.hemoglobin  GCS    ageCat  Spironolactone tablet
# 0      0.724655          0.696010  1.0  0.666667                    1.0
# 1      0.440000          0.226190  1.0  0.533333                    1.0
# 2      0.440000          0.410714  1.0  0.800000                    1.0
# 3      0.724655          0.696010  1.0  0.666667                    1.0
# 4      0.724655          0.696010  1.0  0.266667                    1.0
#
# [5 rows x 129 columns]

# %%
X = df.drop('Spironolactone tablet',axis='columns')
y = testLabels = df['Spironolactone tablet'].astype(np.float32)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# 1.0    1463
# 0.0     139
# Name: Spironolactone tablet, dtype: int64

# %%
y.value_counts()
# Out:
# 1.0    1829
# 0.0     174
# Name: Spironolactone tablet, dtype: int64

# %%
1185/818
# Out:
# 1.4486552567237163

# %%
y_test.value_counts()
# Out:
# 1.0    366
# 0.0     35
# Name: Spironolactone tablet, dtype: int64

# %%
X_train.shape
# Out:
# (1602, 128)

# %%
X_test.shape
# Out:
# (401, 128)

# %%
X_train[:10]
# Out:
#       gender  body.temperature     pulse  respiration  \
# 890      0.0          0.185714  0.297980     0.500000
# 133      1.0          0.157143  0.641414     0.722222
# 1034     0.0          0.214286  0.333333     0.500000
# 1158     1.0          0.271429  0.378788     0.527778
# 1311     0.0          0.214286  0.303030     0.472222
# 517      0.0          0.157143  0.424242     0.555556
# 853      0.0          0.214286  0.404040     0.555556
# 743      0.0          0.200000  0.313131     0.527778
# 997      1.0          0.185714  0.303030     0.500000
# 350      1.0          0.214286  0.398990     0.472222
#
#       systolic.blood.pressure  diastolic.blood.pressure       map       BMI  \
# 890                  0.603175                  0.342466  0.463235  0.036053
# 133                  0.376984                  0.479452  0.431985  0.040905
# 1034                 0.492063                  0.479452  0.485294  0.043263
# 1158                 0.642857                  0.657534  0.650735  0.042816
# 1311                 0.376984                  0.438356  0.409926  0.062140
# 517                  0.476190                  0.410959  0.441176  0.052795
# 853                  0.476190                  0.547945  0.514706  0.050505
# 743                  0.563492                  0.561644  0.562500  0.065210
# 997                  0.496032                  0.479452  0.487132  0.051235
# 350                  0.555556                  0.547945  0.551471  0.062632
#
#       type.of.heart.failure  NYHA.cardiac.function.classification  ...  \
# 890                     1.0                                   1.0  ...
# 133                     1.0                                   1.0  ...
# 1034                    0.0                                   0.5  ...
# 1158                    1.0                                   0.5  ...
# 1311                    1.0                                   0.5  ...
# 517                     1.0                                   1.0  ...
# 853                     1.0                                   0.5  ...
# 743                     1.0                                   0.0  ...
# 997                     1.0                                   1.0  ...
# 350                     1.0                                   1.0  ...
#
#       measured.bicarbonate  carboxyhemoglobin  oxygen.saturation  \
# 890               0.418060           0.229624           0.954472
# 133               0.306043           0.056604           0.133333
# 1034              0.395712           0.018868           0.986667
# 1158              0.343080           0.056604           0.986667
# 1311              0.407407           0.037736           0.946667
# 517               0.389864           0.150943           0.973333
# 853               0.418060           0.229624           0.954472
# 743               0.418060           0.229624           0.954472
# 997               0.282651           0.150943           0.986667
# 350               0.418060           0.229624           0.954472
#
#       partial.oxygen.pressure  oxyhemoglobin  anion.gap  free.calcium  \
# 890                  0.284024       0.941835   0.380276      0.724655
# 133                  0.034043       0.144385   0.567929      0.380000
# 1034                 0.710638       1.000000   0.354120      0.520000
# 1158                 0.642553       0.994652   0.356347      0.420000
# 1311                 0.289362       0.954545   0.287305      0.400000
# 517                  0.336170       0.970588   0.385301      0.420000
# 853                  0.284024       0.941835   0.380276      0.724655
# 743                  0.284024       0.941835   0.380276      0.724655
# 997                  0.561702       0.982620   0.389755      0.360000
# 350                  0.284024       0.941835   0.380276      0.724655
#
#       total.hemoglobin       GCS    ageCat
# 890           0.696010  1.000000  0.800000
# 133           0.577381  0.666667  0.666667
# 1034          0.547619  1.000000  0.800000
# 1158          0.547619  1.000000  0.800000
# 1311          0.482143  1.000000  0.666667
# 517           0.630952  1.000000  0.666667
# 853           0.696010  1.000000  0.533333
# 743           0.696010  1.000000  0.666667
# 997           0.357143  1.000000  0.800000
# 350           0.696010  1.000000  0.800000
#
# [10 rows x 128 columns]

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix , classification_report

# %%
def ANN(X_train, y_train, X_test, y_test, loss, weights):
    model = keras.Sequential([
        keras.layers.Dense(50, input_dim=128
                           , activation='relu'),
        keras.layers.Dense(15, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='rmsprop', loss=loss, metrics=['accuracy'])
    
    if weights == -1:
        model.fit(X_train, y_train, epochs=50)
    else:
        model.fit(X_train, y_train, epochs=50, class_weight = weights)
    
    print(model.evaluate(X_test, y_test))
    
    y_preds = model.predict(X_test)
    y_preds = np.round(y_preds)
    
    print("Classification Report: \n", classification_report(y_test, y_preds))
    
    return y_preds

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 51/51 [==============================] - 1s 1ms/step - loss: 0.3099 - accuracy: 0.9132
# Epoch 2/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2863 - accuracy: 0.9132
# Epoch 3/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2812 - accuracy: 0.9132
# Epoch 4/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2724 - accuracy: 0.9132
# Epoch 5/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2706 - accuracy: 0.9132
# Epoch 6/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2644 - accuracy: 0.9132
# Epoch 7/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2593 - accuracy: 0.9132
# Epoch 8/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2555 - accuracy: 0.9139
# Epoch 9/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2575 - accuracy: 0.9145
# Epoch 10/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.9139
# Epoch 11/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.9157
# Epoch 12/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.9132
# Epoch 13/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2432 - accuracy: 0.9164
# Epoch 14/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2432 - accuracy: 0.9151
# Epoch 15/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.9176
# Epoch 16/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2398 - accuracy: 0.9170
# Epoch 17/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2405 - accuracy: 0.9176
# Epoch 18/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2392 - accuracy: 0.9132
# Epoch 19/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2338 - accuracy: 0.9176
# Epoch 20/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2350 - accuracy: 0.9182
# Epoch 21/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2317 - accuracy: 0.9195
# Epoch 22/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2314 - accuracy: 0.9201
# Epoch 23/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2278 - accuracy: 0.9232
# Epoch 24/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2271 - accuracy: 0.9220
# Epoch 25/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2245 - accuracy: 0.9220
# Epoch 26/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2234 - accuracy: 0.9226
# Epoch 27/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2244 - accuracy: 0.9226
# Epoch 28/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2206 - accuracy: 0.9226
# Epoch 29/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2198 - accuracy: 0.9251
# Epoch 30/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2172 - accuracy: 0.9276
# Epoch 31/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9232
# Epoch 32/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2172 - accuracy: 0.9251
# Epoch 33/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2142 - accuracy: 0.9232
# Epoch 34/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2136 - accuracy: 0.9257
# Epoch 35/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2129 - accuracy: 0.9263
# Epoch 36/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2088 - accuracy: 0.9257
# Epoch 37/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2065 - accuracy: 0.9257
# Epoch 38/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2061 - accuracy: 0.9301
# Epoch 39/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2039 - accuracy: 0.9307
# Epoch 40/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2039 - accuracy: 0.9288
# Epoch 41/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2007 - accuracy: 0.9326
# Epoch 42/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.1999 - accuracy: 0.9320
# Epoch 43/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.1952 - accuracy: 0.9351
# Epoch 44/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.1938 - accuracy: 0.9332
# Epoch 45/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.1958 - accuracy: 0.9320
# Epoch 46/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.1897 - accuracy: 0.9351
# Epoch 47/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.1922 - accuracy: 0.9313
# Epoch 48/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.1833 - accuracy: 0.9326
# Epoch 49/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.1815 - accuracy: 0.9363
# Epoch 50/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.1819 - accuracy: 0.9376
# 13/13 [==============================] - 0s 748us/step - loss: 0.3487 - accuracy: 0.8753
# [0.34870314598083496, 0.8753117322921753]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.26      0.23      0.24        35
#          1.0       0.93      0.94      0.93       366
#
#     accuracy                           0.88       401
#    macro avg       0.59      0.58      0.59       401
# weighted avg       0.87      0.88      0.87       401

# %%
X = df.drop('Spironolactone tablet',axis='columns')
y = testLabels = df['Spironolactone tablet'].astype(np.float32)

# %% [markdown]
# ### Undersampling

# %%
q = "Atorvastatin cal"

# %%
count_class_0, count_class_1 = df[q].value_counts()[0], df[q].value_counts()[1]

# Divide by class
df_class_0 = df[df[q] == 0]
df_class_1 = df[df[q] == 1]

# %%
if count_class_0>count_class_1:
    df_class_0_under = df_class_0.sample(count_class_1)
    df_test_under = pd.concat([df_class_0_under, df_class_1], axis=0)
else:
    df_class_1_under = df_class_1.sample(count_class_0)
    df_test_under = pd.concat([df_class_1_under, df_class_0], axis=0)

# %%
print('Random under-sampling:')
print(df_test_under['Spironolactone tablet'].value_counts())
# Out:
# Random under-sampling:
# 1.0    174
# 0.0    174
# Name: Spironolactone tablet, dtype: int64

# %%
# # Undersample 0-class and concat the DataFrames of both class
# # df_class_1_under = df_class_1.sample(count_class_0)
# # df_test_under = pd.concat([df_class_1_under, df_class_1], axis=0)
# df_class_1_under = df_class_1.sample(count_class_0)
# df_test_under = pd.concat([df_class_1_under, df_class_0], axis=0)

# print('Random under-sampling:')
# print(df_test_under['Spironolactone tablet'].value_counts())
# Out:
# Random under-sampling:
# 1.0    174
# 0.0    174
# Name: Spironolactone tablet, dtype: int64

# %%
X = df_test_under.drop('sulfotanshinone sodium injection',axis='columns')
y = df_test_under['sulfotanshinone sodium injection']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0.0    455
# 1.0    455
# Name: sulfotanshinone sodium injection, dtype: int64

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 72/72 [==============================] - 1s 1ms/step - loss: 0.6908 - accuracy: 0.5414
# Epoch 2/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.6735 - accuracy: 0.5920
# Epoch 3/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.6559 - accuracy: 0.6238
# Epoch 4/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.6371 - accuracy: 0.6517
# Epoch 5/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.6195 - accuracy: 0.6656
# Epoch 6/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.6032 - accuracy: 0.6787
# Epoch 7/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.5882 - accuracy: 0.6953
# Epoch 8/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.5735 - accuracy: 0.7053
# Epoch 9/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.5582 - accuracy: 0.7267
# Epoch 10/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.5447 - accuracy: 0.7371
# Epoch 11/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.5311 - accuracy: 0.7446
# Epoch 12/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.5172 - accuracy: 0.7568
# Epoch 13/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.5028 - accuracy: 0.7698
# Epoch 14/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.4896 - accuracy: 0.7825
# Epoch 15/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.4761 - accuracy: 0.7842
# Epoch 16/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.4619 - accuracy: 0.7982
# Epoch 17/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.8065
# Epoch 18/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.4346 - accuracy: 0.8160
# Epoch 19/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.4211 - accuracy: 0.8300
# Epoch 20/50
# 72/72 [==============================] - 0s 2ms/step - loss: 0.4084 - accuracy: 0.8300
# Epoch 21/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.3955 - accuracy: 0.8426
# Epoch 22/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.3815 - accuracy: 0.8474
# Epoch 23/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.3689 - accuracy: 0.8540
# Epoch 24/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.3562 - accuracy: 0.8557
# Epoch 25/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.3440 - accuracy: 0.8697
# Epoch 26/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.3326 - accuracy: 0.8749
# Epoch 27/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.3195 - accuracy: 0.8775
# Epoch 28/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.3083 - accuracy: 0.8901
# Epoch 29/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2967 - accuracy: 0.8967
# Epoch 30/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2870 - accuracy: 0.8963
# Epoch 31/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2762 - accuracy: 0.9041
# Epoch 32/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2659 - accuracy: 0.9093
# Epoch 33/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2563 - accuracy: 0.9180
# Epoch 34/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2466 - accuracy: 0.9180
# Epoch 35/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2360 - accuracy: 0.9202
# Epoch 36/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2283 - accuracy: 0.9250
# Epoch 37/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2199 - accuracy: 0.9285
# Epoch 38/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2102 - accuracy: 0.9364
# Epoch 39/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.2031 - accuracy: 0.9377
# Epoch 40/50
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.9412
# Epoch 41/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9451
# Epoch 42/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1786 - accuracy: 0.9481
# Epoch 43/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1709 - accuracy: 0.9481
# Epoch 44/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1634 - accuracy: 0.9534
# Epoch 45/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1570 - accuracy: 0.9520
# Epoch 46/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1497 - accuracy: 0.9590
# Epoch 47/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1428 - accuracy: 0.9608
# Epoch 48/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1383 - accuracy: 0.9629
# Epoch 49/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1304 - accuracy: 0.9673
# Epoch 50/50
# 72/72 [==============================] - 0s 1ms/step - loss: 0.1258 - accuracy: 0.9677
# 18/18 [==============================] - 1s 23ms/step - loss: 0.6099 - accuracy: 0.8049
# [0.6099343299865723, 0.8048780560493469]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.69      0.78       287
#          1.0       0.75      0.92      0.82       287
#
#     accuracy                           0.80       574
#    macro avg       0.82      0.80      0.80       574
# weighted avg       0.82      0.80      0.80       574

# %% [markdown]
# # Some feature will be tried along with over sampling and then running on the neural network

# %%
X = df.drop('Spironolactone tablet',axis='columns')
y = df['Spironolactone tablet']

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X)
PCA_df = pd.DataFrame(data = X_pca)
PCA_df = pd.concat([PCA_df, df['Spironolactone tablet']], axis = 1)
PCA_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.523476 -0.238780  0.704734 -0.251208 -0.704963  0.083239 -0.016321
# 1  0.170270 -0.465586 -0.305915 -0.404152 -0.197291  0.284409 -0.234281
# 2  0.654504  0.359562 -0.358608 -0.289298 -0.006726 -0.024271 -0.087419
# 3 -0.045029  0.771255  0.576467 -0.112582 -0.453351 -0.281525  0.753308
# 4 -0.753907 -0.061010 -0.256266 -0.156085  0.005529  0.046611 -0.245375
#
#           7         8         9  ...        41        42        43        44  \
# 0 -0.338960 -0.101965 -0.320476  ...  0.138977 -0.090525  0.044719 -0.039023
# 1 -0.308266  0.124785 -0.735082  ...  0.086144  0.077468 -0.026543 -0.035970
# 2  0.293584 -0.030858 -0.270481  ... -0.082718  0.154134 -0.006525 -0.048231
# 3 -0.256638 -0.458042  0.048076  ... -0.047436 -0.093628 -0.014237  0.117447
# 4 -0.039222 -0.447446  0.192799  ...  0.002370  0.107162  0.069440  0.113330
#
#          45        46        47        48        49  Spironolactone tablet
# 0 -0.074408  0.051322  0.048233 -0.095420 -0.117281                    1.0
# 1 -0.196330 -0.088867 -0.180740 -0.027363  0.073743                    1.0
# 2 -0.018546  0.037308  0.100942 -0.006716  0.212511                    1.0
# 3  0.159251 -0.136388 -0.017576  0.007260  0.066017                    1.0
# 4  0.017976 -0.023594 -0.014171 -0.010660  0.057907                    1.0
#
# [5 rows x 51 columns]

# %%
# Class count
count_class_0, count_class_1 = PCA_df['Spironolactone tablet'].value_counts(ascending=True)
# Divide by class
df_class_0 = PCA_df[PCA_df['Spironolactone tablet'] == 0]
df_class_1 = PCA_df[PCA_df['Spironolactone tablet'] == 1]

# %%
PCA_df['Spironolactone tablet'].value_counts(ascending =True)
# Out:
# 0.0     174
# 1.0    1829
# Name: Spironolactone tablet, dtype: int64

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_0_over = df_class_0.sample(count_class_1,replace=True)
print(df_class_1_over.shape)
df_test_over = pd.concat([df_class_0_over, df_class_1], axis=0)

print('Random over-sampling:')
print(df_test_over['Spironolactone tablet'].value_counts())
# Out:
# (1829, 51)
# Random over-sampling:
# 0.0    1829
# 1.0    1829
# Name: Spironolactone tablet, dtype: int64

# %%
X = df_test_over.drop('Spironolactone tablet',axis='columns')
y = df_test_over['Spironolactone tablet']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0.0    1463
# 1.0    1463
# Name: Spironolactone tablet, dtype: int64

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 92/92 [==============================] - 1s 1ms/step - loss: 0.6679 - accuracy: 0.5957
# Epoch 2/50
# 92/92 [==============================] - 0s 1ms/step - loss: 0.5935 - accuracy: 0.7180
# Epoch 3/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.5301 - accuracy: 0.7515
# Epoch 4/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.7785
# Epoch 5/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.4409 - accuracy: 0.8018
# Epoch 6/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.4047 - accuracy: 0.8213
# Epoch 7/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.3703 - accuracy: 0.8455
# Epoch 8/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.8698
# Epoch 9/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.3030 - accuracy: 0.8835
# Epoch 10/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2717 - accuracy: 0.9012
# Epoch 11/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2420 - accuracy: 0.9180
# Epoch 12/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2142 - accuracy: 0.9313
# Epoch 13/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.1888 - accuracy: 0.9460
# Epoch 14/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.1647 - accuracy: 0.9590
# Epoch 15/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.1443 - accuracy: 0.9634
# Epoch 16/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.1262 - accuracy: 0.9672
# Epoch 17/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.9771
# Epoch 18/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0949 - accuracy: 0.9822
# Epoch 19/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9829
# Epoch 20/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9867
# Epoch 21/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 0.9897
# Epoch 22/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0514 - accuracy: 0.9901
# Epoch 23/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0448 - accuracy: 0.9915
# Epoch 24/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 0.9925
# Epoch 25/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0313 - accuracy: 0.9949
# Epoch 26/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9952
# Epoch 27/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9969
# Epoch 28/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9969
# Epoch 29/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 0.9983
# Epoch 30/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9986
# Epoch 31/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.9990
# Epoch 32/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.9997
# Epoch 33/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.9997
# Epoch 34/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 0.9997
# Epoch 35/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 0.9993
# Epoch 36/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 0.9997
# Epoch 37/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 38/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 39/50
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 40/50
# 92/92 [==============================] - 0s 2ms/step - loss: 6.8562e-04 - accuracy: 1.0000
# Epoch 41/50
# 92/92 [==============================] - 0s 2ms/step - loss: 5.5043e-04 - accuracy: 1.0000
# Epoch 42/50
# 92/92 [==============================] - 0s 2ms/step - loss: 3.6412e-04 - accuracy: 1.0000
# Epoch 43/50
# 92/92 [==============================] - 0s 2ms/step - loss: 2.2664e-04 - accuracy: 1.0000
# Epoch 44/50
# 92/92 [==============================] - 0s 2ms/step - loss: 2.0232e-04 - accuracy: 1.0000
# Epoch 45/50
# 92/92 [==============================] - 0s 2ms/step - loss: 1.1419e-04 - accuracy: 1.0000
# Epoch 46/50
# 92/92 [==============================] - 0s 2ms/step - loss: 8.3055e-05 - accuracy: 1.0000
# Epoch 47/50
# 92/92 [==============================] - 0s 2ms/step - loss: 7.3418e-05 - accuracy: 1.0000
# Epoch 48/50
# 92/92 [==============================] - 0s 2ms/step - loss: 4.0309e-05 - accuracy: 1.0000
# Epoch 49/50
# 92/92 [==============================] - 0s 2ms/step - loss: 2.3992e-05 - accuracy: 1.0000
# Epoch 50/50
# 92/92 [==============================] - 0s 2ms/step - loss: 1.7164e-05 - accuracy: 1.0000
# 23/23 [==============================] - 0s 1ms/step - loss: 0.1592 - accuracy: 0.9754
# [0.15915441513061523, 0.9754098653793335]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98       366
#          1.0       1.00      0.95      0.97       366
#
#     accuracy                           0.98       732
#    macro avg       0.98      0.98      0.98       732
# weighted avg       0.98      0.98      0.98       732

# %% [markdown]
# # Independent Component Analysis

# %%
X = df.drop('Atorvastatin calcium tablet',axis='columns')
y = df['Atorvastatin calcium tablet']

# %%
from sklearn.decomposition import FastICA

ica = FastICA(n_components=50)
X_ica = ica.fit_transform(X)
X_ica = pd.DataFrame(data = X_ica)
X_ica = pd.concat([X_ica, df['Atorvastatin calcium tablet']], axis = 1)
X_ica.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.026759 -0.007166  0.002534 -0.016219 -0.017178 -0.039605 -0.007889
# 1 -0.057077 -0.003648  0.007739 -0.011336  0.030683 -0.011553  0.001094
# 2 -0.018709 -0.006109 -0.036913  0.027446  0.043862  0.008969  0.156490
# 3  0.013716 -0.008610  0.012235 -0.018911  0.006460  0.015596 -0.003199
# 4 -0.019480 -0.003790  0.007386 -0.030866  0.009580  0.009611 -0.002145
#
#           7         8         9  ...        41        42        43        44  \
# 0 -0.008666 -0.003902 -0.011785  ...  0.010132  0.015823  0.018524 -0.010997
# 1  0.028983  0.000562  0.027386  ...  0.013825  0.019737 -0.012656  0.006451
# 2 -0.007510 -0.007174 -0.006700  ...  0.008559 -0.029503 -0.023518  0.008666
# 3  0.031771 -0.006225  0.004087  ...  0.017733 -0.026847 -0.002050 -0.000254
# 4  0.001775 -0.006037 -0.002786  ...  0.005423  0.020016 -0.009046  0.001545
#
#          45        46        47        48        49  \
# 0 -0.001596 -0.006292 -0.004016  0.022649  0.012677
# 1 -0.006121 -0.005673 -0.003378 -0.012386 -0.005178
# 2  0.000649 -0.004304 -0.002995 -0.022176 -0.007495
# 3 -0.002610 -0.002771 -0.003241 -0.015027 -0.015658
# 4 -0.003036 -0.002981 -0.005546 -0.006846  0.005038
#
#    Atorvastatin calcium tablet
# 0                          0.0
# 1                          1.0
# 2                          1.0
# 3                          0.0
# 4                          0.0
#
# [5 rows x 51 columns]

# %%
# Class count
count_class_0, count_class_1 = X_ica['Atorvastatin calcium tablet'].value_counts()

# Divide by class
df_class_0 = X_ica[X_ica['Atorvastatin calcium tablet'] == 0]
df_class_1 = X_ica[X_ica['Atorvastatin calcium tablet'] == 1]

# %%
PCA_df['Atorvastatin calcium tablet'].value_counts()
# Out:
# 0.0    1185
# 1.0     818
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())
# Out:
# Random over-sampling:
# 0.0    1185
# 1.0    1185
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())
# Out:
# Random over-sampling:
# 0.0    1185
# 1.0    1185
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
X = df_test_over.drop('Atorvastatin calcium tablet',axis='columns')
y = df_test_over['Atorvastatin calcium tablet']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0.0    948
# 1.0    948
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.5005
# Epoch 2/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.6926 - accuracy: 0.4995
# Epoch 3/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.6922 - accuracy: 0.5359
# Epoch 4/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.6917 - accuracy: 0.5211
# Epoch 5/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6909 - accuracy: 0.5564
# Epoch 6/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6903 - accuracy: 0.5301
# Epoch 7/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.5538
# Epoch 8/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6880 - accuracy: 0.5923
# Epoch 9/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.5770
# Epoch 10/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5865
# Epoch 11/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.6007
# Epoch 12/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.5939
# Epoch 13/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.5918
# Epoch 14/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6765 - accuracy: 0.6218
# Epoch 15/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6738 - accuracy: 0.6129
# Epoch 16/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6711 - accuracy: 0.6313
# Epoch 17/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6681 - accuracy: 0.6350
# Epoch 18/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6655 - accuracy: 0.6461
# Epoch 19/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6628 - accuracy: 0.6424
# Epoch 20/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6599 - accuracy: 0.6414
# Epoch 21/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6571 - accuracy: 0.6472
# Epoch 22/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.6477
# Epoch 23/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6511 - accuracy: 0.6472
# Epoch 24/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6489 - accuracy: 0.6456
# Epoch 25/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6465 - accuracy: 0.6487
# Epoch 26/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6441 - accuracy: 0.6487
# Epoch 27/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6413 - accuracy: 0.6493
# Epoch 28/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6400 - accuracy: 0.6519
# Epoch 29/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6383 - accuracy: 0.6482
# Epoch 30/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6369 - accuracy: 0.6503
# Epoch 31/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6350 - accuracy: 0.6508
# Epoch 32/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6337 - accuracy: 0.6519
# Epoch 33/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6328 - accuracy: 0.6498
# Epoch 34/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6314 - accuracy: 0.6498
# Epoch 35/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6304 - accuracy: 0.6482
# Epoch 36/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6295 - accuracy: 0.6535
# Epoch 37/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6285 - accuracy: 0.6482
# Epoch 38/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.6503
# Epoch 39/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6262 - accuracy: 0.6519
# Epoch 40/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6265 - accuracy: 0.6503
# Epoch 41/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6258 - accuracy: 0.6508
# Epoch 42/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6246 - accuracy: 0.6540
# Epoch 43/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6246 - accuracy: 0.6514
# Epoch 44/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6243 - accuracy: 0.6503
# Epoch 45/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6235 - accuracy: 0.6582
# Epoch 46/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6230 - accuracy: 0.6582
# Epoch 47/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6226 - accuracy: 0.6530
# Epoch 48/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6225 - accuracy: 0.6493
# Epoch 49/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6219 - accuracy: 0.6535
# Epoch 50/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6215 - accuracy: 0.6582
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6505 - accuracy: 0.5992
# [0.6504685878753662, 0.5991561412811279]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.59      0.63      0.61       237
#          1.0       0.61      0.57      0.59       237
#
#     accuracy                           0.60       474
#    macro avg       0.60      0.60      0.60       474
# weighted avg       0.60      0.60      0.60       474

# %% [markdown]
# # Linear Discriminant Analysis (LDA)

# %%
X = df.drop('Atorvastatin calcium tablet',axis='columns')
y = df['Atorvastatin calcium tablet']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=1)

# run an LDA and use it to transform the features
X_lda = lda.fit(X, y).transform(X)
X_lda = pd.DataFrame(data = X_lda)
X_lda = pd.concat([X_lda, df['Atorvastatin calcium tablet']], axis = 1)
X_lda.head()

# %%
X_lda['Atorvastatin calcium tablet'].value_counts()

# %%
# Class count
count_class_0, count_class_1 = X_lda['Atorvastatin calcium tablet'].value_counts()

# Divide by class
df_class_0 = X_lda[X_lda['Atorvastatin calcium tablet'] == 0]
df_class_1 = X_lda[X_lda['Atorvastatin calcium tablet'] == 1]

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())

# %%
X = df_test_over.drop('Atorvastatin calcium tablet',axis='columns')
y = df_test_over['Atorvastatin calcium tablet']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)

# %% [markdown]
# # Auto Encoder

# %%
X = df.drop('Atorvastatin calcium tablet',axis='columns')
y = df['Atorvastatin calcium tablet']

# %%
from keras.layers import Input, Dense
from keras.models import Model

input_layer = Input(shape=(X.shape[1],))
encoded = Dense(50, activation='relu')(input_layer)
decoded = Dense(X.shape[1], activation='softmax')(encoded)
autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

X1, X2, Y1, Y2 = train_test_split(X, X, test_size=0.3, random_state=101)

autoencoder.fit(X1, Y1,
                epochs=100,
                batch_size=300,
                shuffle=True,
                verbose = 30,
                validation_data=(X2, Y2))

encoder = Model(input_layer, encoded)
X_ae = encoder.predict(X)
# Out:
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100

# %%
X_ae_pd = pd.DataFrame(data = X_ae)
X_ae_pd = pd.concat([X_ae_pd, df['Atorvastatin calcium tablet']], axis = 1)
X_ae_pd.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.494850  1.302103  2.559792  3.012529  1.642494  1.455151  2.133530
# 1  1.759385  0.730524  2.519247  2.766512  1.866066  0.924013  1.154596
# 2  1.783100  0.706636  1.080098  2.507479  1.995273  1.127247  1.983983
# 3  1.516266  1.320563  1.695970  2.454483  1.633047  1.244698  2.882100
# 4  1.165298  1.817460  1.603848  2.815920  2.332255  0.920788  2.703030
#
#           7    8         9  ...        41   42        43   44        45   46  \
# 0  2.531312  0.0  2.211798  ...  1.236068  0.0  1.918516  0.0  1.125507  0.0
# 1  2.792603  0.0  1.492473  ...  1.521834  0.0  1.663635  0.0  1.524203  0.0
# 2  2.257699  0.0  1.792863  ...  2.871765  0.0  1.953951  0.0  1.321721  0.0
# 3  2.889009  0.0  1.436093  ...  2.602617  0.0  2.377555  0.0  0.873436  0.0
# 4  2.326656  0.0  2.282255  ...  1.582348  0.0  1.800320  0.0  1.778236  0.0
#
#     47   48        49  Atorvastatin calcium tablet
# 0  0.0  0.0  2.031941                          0.0
# 1  0.0  0.0  1.670963                          1.0
# 2  0.0  0.0  2.504710                          1.0
# 3  0.0  0.0  2.652916                          0.0
# 4  0.0  0.0  1.983365                          0.0
#
# [5 rows x 51 columns]

# %%
# Class count
count_class_0, count_class_1 = X_ae_pd['Atorvastatin calcium tablet'].value_counts()

# Divide by class
df_class_0 = X_ae_pd[X_ae_pd['Atorvastatin calcium tablet'] == 0]
df_class_1 = X_ae_pd[X_ae_pd['Atorvastatin calcium tablet'] == 1]

# %%
X_ae_pd['Atorvastatin calcium tablet'].value_counts()
# Out:
# 0.0    1185
# 1.0     818
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
# # Class count
# count_class_0, count_class_1 = X_ae_pd['Atorvastatin calcium tablet'].value_counts()

# # Divide by class
# df_class_0 = X_ae_pd[X_lda['Atorvastatin calcium tablet'] == 0]
# df_class_1 = X_lda[X_lda['Atorvastatin calcium tablet'] == 1]

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())
# Out:
# Random over-sampling:
# 0.0    1185
# 1.0    1185
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
X = df_test_over.drop('Atorvastatin calcium tablet',axis='columns')
y = df_test_over['Atorvastatin calcium tablet']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# # Oversample 1-class and concat the DataFrames of both classes
# df_class_1_over = df_class_1.sample(count_class_0, replace=True)
# df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

# print('Random over-sampling:')
# print(df_test_over['Atorvastatin calcium tablet'].value_counts())

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0.0    948
# 1.0    948
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 1s 1ms/step - loss: 0.7010 - accuracy: 0.4931
# Epoch 2/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6939 - accuracy: 0.5121
# Epoch 3/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.5090
# Epoch 4/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.4958
# Epoch 5/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4852
# Epoch 6/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.5026
# Epoch 7/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.5105
# Epoch 8/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.5116
# Epoch 9/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.4963
# Epoch 10/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5047
# Epoch 11/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.5105
# Epoch 12/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5127
# Epoch 13/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.5158
# Epoch 14/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.5105
# Epoch 15/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5137
# Epoch 16/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6920 - accuracy: 0.5158
# Epoch 17/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5116
# Epoch 18/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.5169
# Epoch 19/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6917 - accuracy: 0.5222
# Epoch 20/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6920 - accuracy: 0.5121
# Epoch 21/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5137
# Epoch 22/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6915 - accuracy: 0.5227
# Epoch 23/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5185
# Epoch 24/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5174
# Epoch 25/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6912 - accuracy: 0.5227
# Epoch 26/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.5200
# Epoch 27/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.5258
# Epoch 28/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6907 - accuracy: 0.5253
# Epoch 29/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5290
# Epoch 30/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6907 - accuracy: 0.5185
# Epoch 31/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5243
# Epoch 32/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6903 - accuracy: 0.5264
# Epoch 33/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.5274
# Epoch 34/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6903 - accuracy: 0.5332
# Epoch 35/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6904 - accuracy: 0.5338
# Epoch 36/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.5285
# Epoch 37/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.5306
# Epoch 38/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.5248
# Epoch 39/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.5311
# Epoch 40/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6888 - accuracy: 0.5343
# Epoch 41/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6888 - accuracy: 0.5348
# Epoch 42/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6878 - accuracy: 0.5417
# Epoch 43/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6880 - accuracy: 0.5417
# Epoch 44/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.5454
# Epoch 45/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5575
# Epoch 46/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.5506
# Epoch 47/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5422
# Epoch 48/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5485
# Epoch 49/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5443
# Epoch 50/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5512
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6711 - accuracy: 0.6013
# [0.6710619330406189, 0.6012658476829529]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.59      0.64      0.62       237
#          1.0       0.61      0.56      0.58       237
#
#     accuracy                           0.60       474
#    macro avg       0.60      0.60      0.60       474
# weighted avg       0.60      0.60      0.60       474
