# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("random_imputed.csv",index_col=[0])
df1.sample(5)
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 804237                 0              36.5     65           18
# 780976                 0              36.0    116           22
# 736630                 0              36.6    101           18
# 834500                 0              36.3     83           18
# 757630                 0              36.2     60           18
#
#                   systolic.blood.pressure  diastolic.blood.pressure    map  \
# inpatient.number
# 804237                                124                        70   88.0
# 780976                                150                        90  110.0
# 736630                                134                        74   94.0
# 834500                                126                        66   86.0
# 757630                                134                        68   90.0
#
#                         BMI  type.of.heart.failure  \
# inpatient.number
# 804237            19.979188                      2
# 780976            23.804801                      2
# 736630            15.241579                      2
# 834500            18.080210                      0
# 757630            21.082813                      2
#
#                   NYHA.cardiac.function.classification  ...  \
# inpatient.number                                        ...
# 804237                                               2  ...
# 780976                                               4  ...
# 736630                                               4  ...
# 834500                                               3  ...
# 757630                                               3  ...
#
#                   measured.bicarbonate  carboxyhemoglobin  oxygen.saturation  \
# inpatient.number
# 804237                       23.246503           1.217008          96.585423
# 780976                       23.000000           0.200000          99.000000
# 736630                       23.246503           1.217008          96.585423
# 834500                       23.246503           1.217008          96.585423
# 757630                       23.246503           1.217008          96.585423
#
#                   partial.oxygen.pressure  oxyhemoglobin  anion.gap  \
# inpatient.number
# 804237                           86.74564      94.749285  15.874385
# 780976                          243.00000      98.700000  15.100000
# 736630                           86.74564      94.749285  15.874385
# 834500                           86.74564      94.749285  15.874385
# 757630                           86.74564      94.749285  15.874385
#
#                   free.calcium  total.hemoglobin  GCS  ageCat
# inpatient.number
# 804237                1.252327        151.929679   15      75
# 780976                1.090000        102.000000   15      85
# 736630                1.252327        151.929679   14      65
# 834500                1.252327        151.929679   15      85
# 757630                1.252327        151.929679   15      75
#
# [5 rows x 128 columns]

# %%
df3=pd.read_csv("drug_onehot_latest.csv",index_col=[0])
df3.head()
# Out:
#                   sulfotanshinone sodium injection  Furosemide tablet  \
# inpatient.number
# 722128                                           0                  1
# 723327                                           0                  1
# 723617                                           0                  0
# 724385                                           0                  1
# 725509                                           0                  1
#
#                   Meglumine Adenosine Cyclophosphate for injection  \
# inpatient.number
# 722128                                                           0
# 723327                                                           0
# 723617                                                           0
# 724385                                                           0
# 725509                                                           0
#
#                   Furosemide injection  Milrinone injection  \
# inpatient.number
# 722128                               1                    1
# 723327                               1                    1
# 723617                               1                    0
# 724385                               1                    1
# 725509                               1                    1
#
#                   Deslanoside injection  Torasemide tablet  \
# inpatient.number
# 722128                                1                  0
# 723327                                1                  1
# 723617                                0                  0
# 724385                                1                  0
# 725509                                1                  1
#
#                   Benazepril hydrochloride tablet  \
# inpatient.number
# 722128                                          0
# 723327                                          0
# 723617                                          0
# 724385                                          0
# 725509                                          0
#
#                   Atorvastatin calcium tablet  Digoxin tablet  \
# inpatient.number
# 722128                                      0               1
# 723327                                      1               1
# 723617                                      1               0
# 724385                                      0               1
# 725509                                      0               1
#
#                   Hydrochlorothiazide tablet  Spironolactone tablet  \
# inpatient.number
# 722128                                     0                      1
# 723327                                     0                      1
# 723617                                     0                      1
# 724385                                     0                      1
# 725509                                     0                      1
#
#                   Valsartan Dispersible tablet  \
# inpatient.number
# 722128                                       0
# 723327                                       1
# 723617                                       0
# 724385                                       0
# 725509                                       0
#
#                   Dobutamine hydrochloride injection  \
# inpatient.number
# 722128                                             0
# 723327                                             0
# 723617                                             0
# 724385                                             0
# 725509                                             0
#
#                   Isoprenaline Hydrochloride injection  \
# inpatient.number
# 722128                                               0
# 723327                                               0
# 723617                                               0
# 724385                                               0
# 725509                                               0
#
#                   Nitroglycerin injection  Shenfu injection  \
# inpatient.number
# 722128                                  0                 0
# 723327                                  0                 0
# 723617                                  0                 0
# 724385                                  0                 0
# 725509                                  0                 1
#
#                   Isosorbide Mononitrate Sustained Release tablet
# inpatient.number
# 722128                                                          0
# 723327                                                          1
# 723617                                                          0
# 724385                                                          0
# 725509                                                          0

# %%
df2=df3['Atorvastatin calcium tablet']
df2 = df2.to_frame()

# %%
df2.head()
# Out:
#                   Atorvastatin calcium tablet
# inpatient.number
# 722128                                      0
# 723327                                      1
# 723617                                      1
# 724385                                      0
# 725509                                      0

# %%
df=pd.concat([df1,df2],axis=1)

# %%
df.head()
# Out:
#                   gender  body.temperature  pulse  respiration  \
# inpatient.number
# 722128                 0              36.9     66           18
# 723327                 0              36.0     72           21
# 723617                 1              36.4     70           20
# 724385                 1              36.7    129           22
# 725509                 0              36.9    100           20
#
#                   systolic.blood.pressure  diastolic.blood.pressure  \
# inpatient.number
# 722128                                121                        56
# 723327                                150                        80
# 723617                                120                        80
# 724385                                122                        86
# 725509                                 95                        65
#
#                          map        BMI  type.of.heart.failure  \
# inpatient.number
# 722128             77.666667  18.590125                      2
# 723327            103.333333  21.644121                      2
# 723617             93.333333  31.111111                      2
# 724385             98.000000  20.134780                      2
# 725509             75.000000  22.031726                      2
#
#                   NYHA.cardiac.function.classification  ...  \
# inpatient.number                                        ...
# 722128                                               4  ...
# 723327                                               4  ...
# 723617                                               3  ...
# 724385                                               3  ...
# 725509                                               3  ...
#
#                   carboxyhemoglobin  oxygen.saturation  \
# inpatient.number
# 722128                     1.217008          96.585423
# 723327                     0.700000          91.000000
# 723617                     0.000000          98.000000
# 724385                     1.217008          96.585423
# 725509                     1.217008          96.585423
#
#                   partial.oxygen.pressure  oxyhemoglobin  anion.gap  \
# inpatient.number
# 722128                           86.74564      94.749285  15.874385
# 723327                           64.00000      90.000000  13.000000
# 723617                          106.00000      97.700000   9.100000
# 724385                           86.74564      94.749285  15.874385
# 725509                           86.74564      94.749285  15.874385
#
#                   free.calcium  total.hemoglobin  GCS  ageCat  \
# inpatient.number
# 722128                1.252327        151.929679   15      75
# 723327                1.110000         73.000000   15      65
# 723617                1.110000        104.000000   15      85
# 724385                1.252327        151.929679   15      75
# 725509                1.252327        151.929679   15      45
#
#                   Atorvastatin calcium tablet
# inpatient.number
# 722128                                      0
# 723327                                      1
# 723617                                      1
# 724385                                      0
# 725509                                      0
#
# [5 rows x 129 columns]

# %%
cols_to_scale = [df.columns]

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_df= scaler.fit_transform(df)

# %%
df = pd.DataFrame(scaled_df,columns = df.columns)

# %%
df.head()
# Out:
#    gender  body.temperature     pulse  respiration  systolic.blood.pressure  \
# 0     0.0          0.271429  0.333333     0.500000                 0.480159
# 1     0.0          0.142857  0.363636     0.583333                 0.595238
# 2     1.0          0.200000  0.353535     0.555556                 0.476190
# 3     1.0          0.242857  0.651515     0.611111                 0.484127
# 4     0.0          0.271429  0.505051     0.555556                 0.376984
#
#    diastolic.blood.pressure       map       BMI  type.of.heart.failure  \
# 0                  0.383562  0.428309  0.046006                    1.0
# 1                  0.547945  0.569853  0.053564                    1.0
# 2                  0.547945  0.514706  0.076992                    1.0
# 3                  0.589041  0.540441  0.049828                    1.0
# 4                  0.445205  0.413603  0.054523                    1.0
#
#    NYHA.cardiac.function.classification  ...  carboxyhemoglobin  \
# 0                                   1.0  ...           0.229624
# 1                                   1.0  ...           0.132075
# 2                                   0.5  ...           0.000000
# 3                                   0.5  ...           0.229624
# 4                                   0.5  ...           0.229624
#
#    oxygen.saturation  partial.oxygen.pressure  oxyhemoglobin  anion.gap  \
# 0           0.954472                 0.284024       0.941835   0.380276
# 1           0.880000                 0.187234       0.878342   0.316258
# 2           0.973333                 0.365957       0.981283   0.229399
# 3           0.954472                 0.284024       0.941835   0.380276
# 4           0.954472                 0.284024       0.941835   0.380276
#
#    free.calcium  total.hemoglobin  GCS    ageCat  Atorvastatin calcium tablet
# 0      0.724655          0.696010  1.0  0.666667                          0.0
# 1      0.440000          0.226190  1.0  0.533333                          1.0
# 2      0.440000          0.410714  1.0  0.800000                          1.0
# 3      0.724655          0.696010  1.0  0.666667                          0.0
# 4      0.724655          0.696010  1.0  0.266667                          0.0
#
# [5 rows x 129 columns]

# %%
X = df.drop('Atorvastatin calcium tablet',axis='columns')
y = testLabels = df['Atorvastatin calcium tablet'].astype(np.float32)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# 0.0    948
# 1.0    654
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
y.value_counts()
# Out:
# 0.0    1185
# 1.0     818
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
1185/818
# Out:
# 1.4486552567237163

# %%
y_test.value_counts()
# Out:
# 0.0    237
# 1.0    164
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
X_train.shape
# Out:
# (1602, 128)

# %%
X_test.shape
# Out:
# (401, 128)

# %%
X_train[:10]
# Out:
#       gender  body.temperature     pulse  respiration  \
# 1486     0.0          0.185714  0.494949     0.555556
# 223      1.0          0.228571  0.353535     0.500000
# 1034     0.0          0.214286  0.333333     0.500000
# 762      0.0          0.142857  0.313131     0.500000
# 188      1.0          0.242857  0.303030     0.527778
# 1909     1.0          0.285714  0.328283     0.500000
# 1087     1.0          0.142857  0.520202     0.555556
# 1955     0.0          0.257143  0.419192     0.500000
# 606      0.0          0.371429  0.414141     0.555556
# 526      0.0          0.228571  0.338384     0.500000
#
#       systolic.blood.pressure  diastolic.blood.pressure       map       BMI  \
# 1486                 0.714286                  0.616438  0.661765  0.054994
# 223                  0.357143                  0.410959  0.386029  0.048805
# 1034                 0.492063                  0.479452  0.485294  0.043263
# 762                  0.388889                  0.458904  0.426471  0.046353
# 188                  0.531746                  0.616438  0.577206  0.063431
# 1909                 0.595238                  0.479452  0.533088  0.045641
# 1087                 0.436508                  0.547945  0.496324  0.066357
# 1955                 0.543651                  0.568493  0.556985  0.052795
# 606                  0.484127                  0.479452  0.481618  0.047097
# 526                  0.515873                  0.465753  0.488971  0.045761
#
#       type.of.heart.failure  NYHA.cardiac.function.classification  ...  \
# 1486                    1.0                                   0.0  ...
# 223                     1.0                                   1.0  ...
# 1034                    0.0                                   0.5  ...
# 762                     1.0                                   0.5  ...
# 188                     1.0                                   0.5  ...
# 1909                    0.0                                   0.0  ...
# 1087                    1.0                                   0.5  ...
# 1955                    1.0                                   0.5  ...
# 606                     0.0                                   0.5  ...
# 526                     1.0                                   1.0  ...
#
#       measured.bicarbonate  carboxyhemoglobin  oxygen.saturation  \
# 1486              0.586745           0.094340           0.986667
# 223               0.348928           0.056604           0.986667
# 1034              0.395712           0.018868           0.986667
# 762               0.615984           0.094340           0.946667
# 188               0.418060           0.229624           0.954472
# 1909              0.418060           0.229624           0.954472
# 1087              0.391813           0.056604           0.986667
# 1955              0.418060           0.229624           0.954472
# 606               0.418060           0.229624           0.954472
# 526               0.578947           0.283019           0.640000
#
#       partial.oxygen.pressure  oxyhemoglobin  anion.gap  free.calcium  \
# 1486                 0.472340       0.982620   0.340757      0.440000
# 223                  0.506383       0.987968   0.296214      0.500000
# 1034                 0.710638       1.000000   0.354120      0.520000
# 762                  0.234043       0.943850   0.400891      0.320000
# 188                  0.284024       0.941835   0.380276      0.724655
# 1909                 0.284024       0.941835   0.380276      0.724655
# 1087                 0.544681       0.989305   0.191537      0.320000
# 1955                 0.284024       0.941835   0.380276      0.724655
# 606                  0.284024       0.941835   0.380276      0.724655
# 526                  0.102128       0.631016   0.360802      0.360000
#
#       total.hemoglobin       GCS    ageCat
# 1486          0.583333  1.000000  0.800000
# 223           0.619048  1.000000  0.533333
# 1034          0.547619  1.000000  0.800000
# 762           0.726190  1.000000  0.400000
# 188           0.696010  0.583333  0.800000
# 1909          0.696010  1.000000  0.800000
# 1087          0.428571  1.000000  0.266667
# 1955          0.696010  1.000000  0.400000
# 606           0.696010  1.000000  0.400000
# 526           0.470238  1.000000  0.800000
#
# [10 rows x 128 columns]

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix , classification_report

# %%
def ANN(X_train, y_train, X_test, y_test, loss, weights):
    model = keras.Sequential([
        keras.layers.Dense(128, input_dim=50, activation='relu'),
        keras.layers.Dense(15, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='rmsprop', loss=loss, metrics=['accuracy'])
    
    if weights == -1:
        model.fit(X_train, y_train, epochs=50)
    else:
        model.fit(X_train, y_train, epochs=50, class_weight = weights)
    
    print(model.evaluate(X_test, y_test))
    
    y_preds = model.predict(X_test)
    y_preds = np.round(y_preds)
    
    print("Classification Report: \n", classification_report(y_test, y_preds))
    
    return y_preds

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 51/51 [==============================] - 1s 1ms/step - loss: 0.6780 - accuracy: 0.5899
# Epoch 2/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6572 - accuracy: 0.6061
# Epoch 3/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6504 - accuracy: 0.6255
# Epoch 4/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6345 - accuracy: 0.6298
# Epoch 5/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6353 - accuracy: 0.6442
# Epoch 6/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6331 - accuracy: 0.6317
# Epoch 7/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6283 - accuracy: 0.6454
# Epoch 8/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6200 - accuracy: 0.6504
# Epoch 9/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6271 - accuracy: 0.6536
# Epoch 10/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6160 - accuracy: 0.6523
# Epoch 11/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6160 - accuracy: 0.6523
# Epoch 12/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6145 - accuracy: 0.6479
# Epoch 13/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6078 - accuracy: 0.6617
# Epoch 14/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.6013 - accuracy: 0.6579
# Epoch 15/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6011 - accuracy: 0.6673
# Epoch 16/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6011 - accuracy: 0.6598
# Epoch 17/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5986 - accuracy: 0.6885
# Epoch 18/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5894 - accuracy: 0.6673
# Epoch 19/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5875 - accuracy: 0.6754
# Epoch 20/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5869 - accuracy: 0.6835
# Epoch 21/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5826 - accuracy: 0.6879
# Epoch 22/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5763 - accuracy: 0.6948
# Epoch 23/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.5752 - accuracy: 0.6923
# Epoch 24/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.5765 - accuracy: 0.6935
# Epoch 25/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5660 - accuracy: 0.7085
# Epoch 26/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5628 - accuracy: 0.7072
# Epoch 27/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5609 - accuracy: 0.7016
# Epoch 28/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5530 - accuracy: 0.7079
# Epoch 29/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.5530 - accuracy: 0.7004
# Epoch 30/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5439 - accuracy: 0.7141
# Epoch 31/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5443 - accuracy: 0.7166
# Epoch 32/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5398 - accuracy: 0.7191
# Epoch 33/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.7210
# Epoch 34/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5377 - accuracy: 0.7210
# Epoch 35/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5263 - accuracy: 0.7272
# Epoch 36/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5275 - accuracy: 0.7316
# Epoch 37/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.5084 - accuracy: 0.7441
# Epoch 38/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.5171 - accuracy: 0.7416
# Epoch 39/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.5052 - accuracy: 0.7503
# Epoch 40/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.5017 - accuracy: 0.7534
# Epoch 41/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.5015 - accuracy: 0.7509
# Epoch 42/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.4897 - accuracy: 0.7541
# Epoch 43/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.4833 - accuracy: 0.7622
# Epoch 44/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.4819 - accuracy: 0.7653
# Epoch 45/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.4758 - accuracy: 0.7722
# Epoch 46/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.4715 - accuracy: 0.7765
# Epoch 47/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.4644 - accuracy: 0.7772
# Epoch 48/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.7784
# Epoch 49/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.4540 - accuracy: 0.7846
# Epoch 50/50
# 51/51 [==============================] - 0s 1ms/step - loss: 0.4523 - accuracy: 0.7765
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.6259
# [0.6924787163734436, 0.6259351372718811]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.68      0.69      0.69       237
#          1.0       0.54      0.53      0.54       164
#
#     accuracy                           0.63       401
#    macro avg       0.61      0.61      0.61       401
# weighted avg       0.62      0.63      0.63       401

# %%
# Class count
count_class_0, count_class_1 = df['Atorvastatin calcium tablet'].value_counts()

# Divide by class
df_class_0 = df[df['Atorvastatin calcium tablet'] == 0]
df_class_1 = df[df['Atorvastatin calcium tablet'] == 1]

# %%
df['Atorvastatin calcium tablet'].value_counts()
# Out:
# 0.0    1185
# 1.0     818
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
# Undersample 0-class and concat the DataFrames of both class
df_class_0_under = df_class_0.sample(count_class_1)
df_test_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df_test_under['Atorvastatin calcium tablet'].value_counts())
# Out:
# Random under-sampling:
# 0.0    818
# 1.0    818
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
X = df_test_under.drop('Atorvastatin calcium tablet',axis='columns')
y = df_test_under['Atorvastatin calcium tablet']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0.0    654
# 1.0    654
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 1s 2ms/step - loss: 0.6864 - accuracy: 0.5443
# Epoch 2/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6724 - accuracy: 0.5864
# Epoch 3/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6590 - accuracy: 0.5887
# Epoch 4/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6473 - accuracy: 0.6284
# Epoch 5/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6473 - accuracy: 0.6254
# Epoch 6/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6369 - accuracy: 0.6307
# Epoch 7/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6410 - accuracy: 0.6376
# Epoch 8/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6385 - accuracy: 0.6300
# Epoch 9/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6243 - accuracy: 0.6483
# Epoch 10/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6217 - accuracy: 0.6567
# Epoch 11/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6155 - accuracy: 0.6476
# Epoch 12/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6153 - accuracy: 0.6483
# Epoch 13/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6071 - accuracy: 0.6728
# Epoch 14/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.6012 - accuracy: 0.6628
# Epoch 15/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.5939 - accuracy: 0.6827
# Epoch 16/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.5995 - accuracy: 0.6713
# Epoch 17/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.5888 - accuracy: 0.6820
# Epoch 18/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.5808 - accuracy: 0.6804
# Epoch 19/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.6934
# Epoch 20/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5771 - accuracy: 0.6888
# Epoch 21/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5613 - accuracy: 0.7057
# Epoch 22/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5663 - accuracy: 0.6980
# Epoch 23/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5577 - accuracy: 0.7156
# Epoch 24/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5534 - accuracy: 0.7164
# Epoch 25/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5465 - accuracy: 0.7248
# Epoch 26/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5427 - accuracy: 0.7148
# Epoch 27/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5318 - accuracy: 0.7286
# Epoch 28/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.5416 - accuracy: 0.7018
# Epoch 29/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5229 - accuracy: 0.7294
# Epoch 30/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5214 - accuracy: 0.7324
# Epoch 31/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5150 - accuracy: 0.7240
# Epoch 32/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.5043 - accuracy: 0.7424
# Epoch 33/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.7446
# Epoch 34/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.7469
# Epoch 35/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4851 - accuracy: 0.7531
# Epoch 36/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.7630
# Epoch 37/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4739 - accuracy: 0.7661
# Epoch 38/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4849 - accuracy: 0.7546
# Epoch 39/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.4647 - accuracy: 0.7768
# Epoch 40/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.4645 - accuracy: 0.7737
# Epoch 41/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.4522 - accuracy: 0.7752
# Epoch 42/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.4430 - accuracy: 0.7844
# Epoch 43/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.7844
# Epoch 44/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.4349 - accuracy: 0.7974
# Epoch 45/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.4329 - accuracy: 0.7859
# Epoch 46/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4311 - accuracy: 0.7928
# Epoch 47/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.7951
# Epoch 48/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.8073
# Epoch 49/50
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8073
# Epoch 50/50
# 41/41 [==============================] - 0s 1ms/step - loss: 0.4068 - accuracy: 0.8081
# 11/11 [==============================] - 0s 2ms/step - loss: 0.7948 - accuracy: 0.5915
# [0.7947543263435364, 0.5914633870124817]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.60      0.54      0.57       164
#          1.0       0.58      0.65      0.61       164
#
#     accuracy                           0.59       328
#    macro avg       0.59      0.59      0.59       328
# weighted avg       0.59      0.59      0.59       328

# %% [markdown]
# # Some feature will be tried along with over sampling and then running on the neural network

# %%
X = df.drop('Atorvastatin calcium tablet',axis='columns')
y = df['Atorvastatin calcium tablet']

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X)
PCA_df = pd.DataFrame(data = X_pca)
PCA_df = pd.concat([PCA_df, df['Atorvastatin calcium tablet']], axis = 1)
PCA_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.523476 -0.238780  0.704734 -0.251208 -0.704963  0.083239 -0.016321
# 1  0.170270 -0.465586 -0.305915 -0.404152 -0.197291  0.284409 -0.234281
# 2  0.654504  0.359562 -0.358608 -0.289298 -0.006726 -0.024271 -0.087419
# 3 -0.045029  0.771255  0.576467 -0.112582 -0.453351 -0.281525  0.753308
# 4 -0.753907 -0.061010 -0.256266 -0.156085  0.005529  0.046611 -0.245375
#
#           7         8         9  ...        41        42        43        44  \
# 0 -0.338960 -0.101965 -0.320476  ...  0.138977 -0.090525  0.044719 -0.039023
# 1 -0.308266  0.124785 -0.735082  ...  0.086144  0.077468 -0.026543 -0.035970
# 2  0.293584 -0.030858 -0.270481  ... -0.082718  0.154134 -0.006525 -0.048231
# 3 -0.256638 -0.458042  0.048076  ... -0.047436 -0.093628 -0.014237  0.117447
# 4 -0.039222 -0.447446  0.192799  ...  0.002370  0.107162  0.069440  0.113330
#
#          45        46        47        48        49  \
# 0 -0.074408  0.051322  0.048233 -0.095420 -0.117281
# 1 -0.196330 -0.088867 -0.180740 -0.027363  0.073743
# 2 -0.018546  0.037308  0.100942 -0.006716  0.212511
# 3  0.159251 -0.136388 -0.017576  0.007260  0.066017
# 4  0.017976 -0.023594 -0.014171 -0.010660  0.057907
#
#    Atorvastatin calcium tablet
# 0                          0.0
# 1                          1.0
# 2                          1.0
# 3                          0.0
# 4                          0.0
#
# [5 rows x 51 columns]

# %%
# Class count
count_class_0, count_class_1 = PCA_df['Atorvastatin calcium tablet'].value_counts()

# Divide by class
df_class_0 = PCA_df[PCA_df['Atorvastatin calcium tablet'] == 0]
df_class_1 = PCA_df[PCA_df['Atorvastatin calcium tablet'] == 1]

# %%
PCA_df['Atorvastatin calcium tablet'].value_counts()
# Out:
# 0.0    1185
# 1.0     818
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())
# Out:
# Random over-sampling:
# 0.0    1185
# 1.0    1185
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
X = df_test_over.drop('Atorvastatin calcium tablet',axis='columns')
y = df_test_over['Atorvastatin calcium tablet']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0.0    948
# 1.0    948
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 1s 1ms/step - loss: 0.6808 - accuracy: 0.5522
# Epoch 2/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.6419 - accuracy: 0.6566
# Epoch 3/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.6095 - accuracy: 0.6809
# Epoch 4/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5841 - accuracy: 0.7004
# Epoch 5/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5666 - accuracy: 0.7089
# Epoch 6/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5511 - accuracy: 0.7162
# Epoch 7/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5341 - accuracy: 0.7321
# Epoch 8/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5181 - accuracy: 0.7389
# Epoch 9/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5011 - accuracy: 0.7637
# Epoch 10/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4853 - accuracy: 0.7785
# Epoch 11/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4678 - accuracy: 0.7843
# Epoch 12/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.8054
# Epoch 13/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.8228
# Epoch 14/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4111 - accuracy: 0.8365
# Epoch 15/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3915 - accuracy: 0.8376
# Epoch 16/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3733 - accuracy: 0.8507
# Epoch 17/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3559 - accuracy: 0.8608
# Epoch 18/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3371 - accuracy: 0.8750
# Epoch 19/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3198 - accuracy: 0.8813
# Epoch 20/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3024 - accuracy: 0.8935
# Epoch 21/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.2857 - accuracy: 0.8998
# Epoch 22/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.2691 - accuracy: 0.9151
# Epoch 23/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.9251
# Epoch 24/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2379 - accuracy: 0.9277
# Epoch 25/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2247 - accuracy: 0.9357
# Epoch 26/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.2110 - accuracy: 0.9372
# Epoch 27/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1986 - accuracy: 0.9436
# Epoch 28/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1840 - accuracy: 0.9483
# Epoch 29/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9531
# Epoch 30/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1641 - accuracy: 0.9583
# Epoch 31/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1512 - accuracy: 0.9657
# Epoch 32/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1393 - accuracy: 0.9604
# Epoch 33/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1291 - accuracy: 0.9705
# Epoch 34/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1202 - accuracy: 0.9715
# Epoch 35/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1090 - accuracy: 0.9763
# Epoch 36/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1039 - accuracy: 0.9773
# Epoch 37/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0928 - accuracy: 0.9847
# Epoch 38/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0846 - accuracy: 0.9810
# Epoch 39/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0764 - accuracy: 0.9852
# Epoch 40/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0683 - accuracy: 0.9889
# Epoch 41/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0630 - accuracy: 0.9884
# Epoch 42/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0572 - accuracy: 0.9905
# Epoch 43/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0499 - accuracy: 0.9937
# Epoch 44/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0453 - accuracy: 0.9947
# Epoch 45/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9958
# Epoch 46/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 0.9979
# Epoch 47/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0307 - accuracy: 0.9984
# Epoch 48/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 0.9968
# Epoch 49/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0227 - accuracy: 0.9984
# Epoch 50/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0203 - accuracy: 0.9984
# 15/15 [==============================] - 0s 2ms/step - loss: 1.0922 - accuracy: 0.7553
# [1.0921977758407593, 0.75527423620224]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.78      0.71      0.74       237
#          1.0       0.73      0.80      0.77       237
#
#     accuracy                           0.76       474
#    macro avg       0.76      0.76      0.75       474
# weighted avg       0.76      0.76      0.75       474

# %% [markdown]
# # Independent Component Analysis

# %%
from sklearn.decomposition import FastICA

ica = FastICA(n_components=3)
X_ica = ica.fit_transform(X)
X_ica = pd.DataFrame(data = X_ica)
X_ica = pd.concat([X_ica, df['Atorvastatin calcium tablet']], axis = 1)
X_ica.head()

# %%
# Class count
count_class_0, count_class_1 = X_ica['Atorvastatin calcium tablet'].value_counts()

# Divide by class
df_class_0 = X_ica[X_ica['Atorvastatin calcium tablet'] == 0]
df_class_1 = X_ica[X_ica['Atorvastatin calcium tablet'] == 1]

# %%
PCA_df['Atorvastatin calcium tablet'].value_counts()

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())

# %%
# Number of classes in training Data
y_train.value_counts()

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)

# %% [markdown]
# # Linear Discriminant Analysis (LDA)

# %%
X = df.drop('Atorvastatin calcium tablet',axis='columns')
y = df['Atorvastatin calcium tablet']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=1)

# run an LDA and use it to transform the features
X_lda = lda.fit(X, y).transform(X)
X_lda = pd.DataFrame(data = X_lda)
X_lda = pd.concat([X_lda, df['Atorvastatin calcium tablet']], axis = 1)
X_lda.head()
# Out:
#           0  Atorvastatin calcium tablet
# 0 -0.771983                          0.0
# 1 -0.547693                          1.0
# 2 -0.541566                          1.0
# 3 -1.149395                          0.0
# 4 -1.632769                          0.0

# %%
X_lda['Atorvastatin calcium tablet'].value_counts()
# Out:
# 0.0    1185
# 1.0     818
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
# Class count
count_class_0, count_class_1 = X_lda['Atorvastatin calcium tablet'].value_counts()

# Divide by class
df_class_0 = X_lda[X_lda['Atorvastatin calcium tablet'] == 0]
df_class_1 = X_lda[X_lda['Atorvastatin calcium tablet'] == 1]

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())
# Out:
# Random over-sampling:
# 0.0    1185
# 1.0    1185
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
X = df_test_over.drop('Atorvastatin calcium tablet',axis='columns')
y = df_test_over['Atorvastatin calcium tablet']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0.0    948
# 1.0    948
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.4989
# Epoch 2/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 3/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 4/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 5/50
# 60/60 [==============================] - 0s 995us/step - loss: nan - accuracy: 0.5000
# Epoch 6/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 7/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 8/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 9/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 10/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 11/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 12/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 13/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 14/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 15/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 16/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 17/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 18/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 19/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 20/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 21/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 22/50
# 60/60 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5000
# Epoch 23/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 24/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 25/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 26/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 27/50
# 60/60 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5000
# Epoch 28/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 29/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 30/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 31/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 32/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 33/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 34/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 35/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 36/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 37/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 38/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 39/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 40/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 41/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 42/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 43/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 44/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 45/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 46/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 47/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 48/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 49/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# Epoch 50/50
# 60/60 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# 15/15 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.5000
# [nan, 0.5]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-217-65b44678c93d> in <module>
#       1 loss = keras.losses.BinaryCrossentropy()
#       2 weights = -1
# ----> 3 y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
#
# <ipython-input-216-7577a53f0847> in ANN(X_train, y_train, X_test, y_test, loss, weights)
#      18     y_preds = np.round(y_preds)
#      19
# ---> 20     print("Classification Report: \n", classification_report(y_test, y_preds))
#      21
#      22     return y_preds
#
# E:\anoconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# E:\anoconda\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1964     """
#    1965
# -> 1966     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1967
#    1968     if labels is None:
#
# E:\anoconda\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      83     check_consistent_length(y_true, y_pred)
#      84     type_true = type_of_target(y_true)
# ---> 85     type_pred = type_of_target(y_pred)
#      86
#      87     y_type = {type_true, type_pred}
#
# E:\anoconda\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     301     if y.dtype.kind == 'f' and np.any(y != y.astype(int)):
#     302         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 303         _assert_all_finite(y)
#     304         return 'continuous' + suffix
#     305
#
# E:\anoconda\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %% [markdown]
# # Auto Encoder

# %%
X = df.drop('Atorvastatin calcium tablet',axis='columns')
y = df['Atorvastatin calcium tablet']

# %%
from keras.layers import Input, Dense
from keras.models import Model

input_layer = Input(shape=(X.shape[1],))
encoded = Dense(3, activation='relu')(input_layer)
decoded = Dense(X.shape[1], activation='softmax')(encoded)
autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

X1, X2, Y1, Y2 = train_test_split(X, X, test_size=0.3, random_state=101)

autoencoder.fit(X1, Y1,
                epochs=100,
                batch_size=300,
                shuffle=True,
                verbose = 30,
                validation_data=(X2, Y2))

encoder = Model(input_layer, encoded)
X_ae = encoder.predict(X)
# Out:
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100

# %%
X_ae_pd = pd.DataFrame(data = X_ae)
X_ae_pd = pd.concat([X_ae_pd, df['Atorvastatin calcium tablet']], axis = 1)
X_ae_pd.head()
# Out:
#           0         1    2  Atorvastatin calcium tablet
# 0  8.412498  8.021321  0.0                          0.0
# 1  7.819915  8.151376  0.0                          1.0
# 2  7.730518  7.773882  0.0                          1.0
# 3  8.482791  8.580993  0.0                          0.0
# 4  8.485265  8.387544  0.0                          0.0

# %%
# Class count
count_class_0, count_class_1 = X_ae_pd['Atorvastatin calcium tablet'].value_counts()

# Divide by class
df_class_0 = X_ae_pd[X_ae_pd['Atorvastatin calcium tablet'] == 0]
df_class_1 = X_ae_pd[X_ae_pd['Atorvastatin calcium tablet'] == 1]

# %%
X_ae_pd['Atorvastatin calcium tablet'].value_counts()
# Out:
# 0.0    1185
# 1.0     818
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
# # Class count
# count_class_0, count_class_1 = X_ae_pd['Atorvastatin calcium tablet'].value_counts()

# # Divide by class
# df_class_0 = X_ae_pd[X_lda['Atorvastatin calcium tablet'] == 0]
# df_class_1 = X_lda[X_lda['Atorvastatin calcium tablet'] == 1]

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())
# Out:
# Random over-sampling:
# 0.0    1185
# 1.0    1185
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over['Atorvastatin calcium tablet'].value_counts())
# Out:
# Random over-sampling:
# 0.0    1185
# 1.0    1185
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0.0    948
# 1.0    948
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 1s 1ms/step - loss: 0.6769 - accuracy: 0.5812
# Epoch 2/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.6412 - accuracy: 0.6619
# Epoch 3/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.6116 - accuracy: 0.6814
# Epoch 4/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5891 - accuracy: 0.6951
# Epoch 5/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.5709 - accuracy: 0.7041
# Epoch 6/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5542 - accuracy: 0.7173
# Epoch 7/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5400 - accuracy: 0.7315
# Epoch 8/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5242 - accuracy: 0.7400
# Epoch 9/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.5087 - accuracy: 0.7463
# Epoch 10/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4932 - accuracy: 0.7664
# Epoch 11/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4758 - accuracy: 0.7827
# Epoch 12/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4588 - accuracy: 0.7880
# Epoch 13/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4400 - accuracy: 0.8080
# Epoch 14/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4231 - accuracy: 0.8117
# Epoch 15/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.4051 - accuracy: 0.8265
# Epoch 16/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3844 - accuracy: 0.8434
# Epoch 17/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3657 - accuracy: 0.8581
# Epoch 18/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3470 - accuracy: 0.8718
# Epoch 19/50
# 60/60 [==============================] - 0s 2ms/step - loss: 0.3271 - accuracy: 0.8819
# Epoch 20/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.3070 - accuracy: 0.8940
# Epoch 21/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.2909 - accuracy: 0.9019
# Epoch 22/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.2729 - accuracy: 0.9093
# Epoch 23/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.2578 - accuracy: 0.9230
# Epoch 24/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.9309
# Epoch 25/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.2241 - accuracy: 0.9357
# Epoch 26/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.2094 - accuracy: 0.9399
# Epoch 27/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1956 - accuracy: 0.9441
# Epoch 28/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1793 - accuracy: 0.9525
# Epoch 29/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1681 - accuracy: 0.9546
# Epoch 30/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1575 - accuracy: 0.9647
# Epoch 31/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1432 - accuracy: 0.9689
# Epoch 32/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1312 - accuracy: 0.9715
# Epoch 33/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1219 - accuracy: 0.9726
# Epoch 34/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1127 - accuracy: 0.9757
# Epoch 35/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.1028 - accuracy: 0.9773
# Epoch 36/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9858
# Epoch 37/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0840 - accuracy: 0.9873
# Epoch 38/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0742 - accuracy: 0.9889
# Epoch 39/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0695 - accuracy: 0.9873
# Epoch 40/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0605 - accuracy: 0.9895
# Epoch 41/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0551 - accuracy: 0.9905
# Epoch 42/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0476 - accuracy: 0.9953
# Epoch 43/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0421 - accuracy: 0.9958
# Epoch 44/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0391 - accuracy: 0.9963
# Epoch 45/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0336 - accuracy: 0.9963
# Epoch 46/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 0.9979
# Epoch 47/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0264 - accuracy: 0.9968
# Epoch 48/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0243 - accuracy: 0.9963
# Epoch 49/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0199 - accuracy: 0.9995
# Epoch 50/50
# 60/60 [==============================] - 0s 1ms/step - loss: 0.0180 - accuracy: 0.9995
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1335 - accuracy: 0.7658
# [1.1335045099258423, 0.7658227682113647]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.68      0.74       237
#          1.0       0.73      0.85      0.78       237
#
#     accuracy                           0.77       474
#    macro avg       0.77      0.77      0.76       474
# weighted avg       0.77      0.77      0.76       474
