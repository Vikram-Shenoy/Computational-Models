# %% [markdown]
# # Reduced number of colmuns

# %%
import pandas as pd
import numpy as np 
from numpy import mean
from numpy import std
from sklearn.datasets import make_multilabel_classification
from sklearn.model_selection import RepeatedKFold
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
pd.options.display.max_rows=None
pd.options.display.max_columns=None
from sklearn.metrics import accuracy_score

# %%
df1=pd.read_csv("random_imputed.csv",index_col=[0])
df2=pd.read_csv("atorv_features.csv",index_col=[0])
df=pd.read_csv("Raw_NaN.csv",index_col=[0])
df3=pd.read_csv("drug_onehot_latest.csv",index_col=[0])

# %%
null_count=df.isnull().sum().sort_values(ascending=False)
percentage=((df.isnull().sum()/df.isnull().count())*100).sort_values(ascending=False)
null_df=pd.concat([null_count,percentage],axis=1,keys=["null_count","percentage"])
null_df
# Out:
#                                                     null_count  percentage
# high.sensitivity.protein                                  1066   53.220170
# mitral.valve.EMS                                          1027   51.273090
# total.hemoglobin                                          1012   50.524214
# oxyhemoglobin                                             1012   50.524214
# carboxyhemoglobin                                         1012   50.524214
# methemoglobin                                             1012   50.524214
# hematocrit.blood.gas                                      1012   50.524214
# reduced.hemoglobin                                        1012   50.524214
# standard.bicarbonate                                      1011   50.474289
# chloride.ion                                              1011   50.474289
# pH                                                        1011   50.474289
# standard.residual.base                                    1011   50.474289
# partial.pressure.of.carbon.dioxide                        1011   50.474289
# total.carbon.dioxide                                      1011   50.474289
# potassium.ion                                             1011   50.474289
# sodium.ion                                                1011   50.474289
# measured.bicarbonate                                      1011   50.474289
# free.calcium                                              1011   50.474289
# partial.oxygen.pressure                                   1011   50.474289
# oxygen.saturation                                         1011   50.474289
# anion.gap                                                 1011   50.474289
# measured.residual.base                                    1011   50.474289
# lactate                                                   1011   50.474289
# glucose.blood.gas                                         1011   50.474289
# left.ventricular.end.diastolic.diameter.LV                 697   34.797803
# nucleotidase                                               526   26.260609
# fucosidase                                                 526   26.260609
# total.bile.acid                                            507   25.312032
# glutamic.oxaloacetic.transaminase                          251   12.531203
# creatine.kinase                                            239   11.932102
# creatine.kinase.isoenzyme.to.creatine.kinase               239   11.932102
# hydroxybutyrate.dehydrogenase                              239   11.932102
# hydroxybutyrate.dehydrogenase.to.lactate.dehydr...         239   11.932102
# lactate.dehydrogenase                                      239   11.932102
# creatine.kinase.isoenzyme                                  239   11.932102
# cholesterol                                                198    9.885172
# low.density.lipoprotein.cholesterol                        198    9.885172
# triglyceride                                               198    9.885172
# high.density.lipoprotein.cholesterol                       198    9.885172
# D.dimer                                                    166    8.287569
# platelet.distribution.width                                103    5.142287
# platelet.hematocrit                                        103    5.142287
# mean.platelet.volume                                       103    5.142287
# glutamyltranspeptidase                                     102    5.092361
# albumin                                                    102    5.092361
# alkaline.phosphatase                                       102    5.092361
# white.globulin.ratio                                       102    5.092361
# total.protein                                              102    5.092361
# total.bilirubin                                            102    5.092361
# direct.bilirubin                                           102    5.092361
# globulin                                                   102    5.092361
# glutamic.pyruvic.transaminase                              102    5.092361
# indirect.bilirubin                                         102    5.092361
# high.sensitivity.troponin                                   79    3.944084
# glomerular.filtration.rate                                  63    3.145282
# prothrombin.activity                                        46    2.296555
# cystatin                                                    41    2.046930
# international.normalized.ratio                              35    1.747379
# brain.natriuretic.peptide                                   35    1.747379
# fibrinogen                                                  34    1.697454
# thrombin.time                                               34    1.697454
# activated.partial.thromboplastin.time                       34    1.697454
# standard.deviation.of.red.blood.cell.distributi...          30    1.497753
# coefficient.of.variation.of.red.blood.cell.dist...          30    1.497753
# hemoglobin                                                  28    1.397903
# mean.hemoglobin.volume                                      28    1.397903
# hematocrit                                                  28    1.397903
# mean.corpuscular.volume                                     28    1.397903
# neutrophil.ratio                                            27    1.347978
# neutrophil.count                                            27    1.347978
# basophil.count                                              27    1.347978
# white.blood.cell                                            27    1.347978
# monocyte.count                                              27    1.347978
# red.blood.cell                                              27    1.347978
# lymphocyte.count                                            27    1.347978
# mean.hemoglobin.concentration                               27    1.347978
# platelet                                                    27    1.347978
# basophil.ratio                                              27    1.347978
# eosinophil.ratio                                            27    1.347978
# eosinophil.count                                            27    1.347978
# monocyte.ratio                                              27    1.347978
# uric.acid                                                   23    1.148278
# urea                                                        23    1.148278
# creatinine.enzymatic.method                                 23    1.148278
# sodium                                                      11    0.549176
# chloride                                                    11    0.549176
# potassium                                                   11    0.549176
# calcium                                                     11    0.549176
# carbon.dioxide.binding.capacity                             11    0.549176
# GCS                                                          0    0.000000
# gender                                                       0    0.000000
# body.temperature                                             0    0.000000
# peptic.ulcer.disease                                         0    0.000000
# Chronic.obstructive.pulmonary.disease                        0    0.000000
# dementia                                                     0    0.000000
# cerebrovascular.disease                                      0    0.000000
# peripheral.vascular.disease                                  0    0.000000
# congestive.heart.failure                                     0    0.000000
# myocardial.infarction                                        0    0.000000
# Killip.grade                                                 0    0.000000
# NYHA.cardiac.function.classification                         0    0.000000
# type.of.heart.failure                                        0    0.000000
# BMI                                                          0    0.000000
# map                                                          0    0.000000
# diastolic.blood.pressure                                     0    0.000000
# systolic.blood.pressure                                      0    0.000000
# respiration                                                  0    0.000000
# pulse                                                        0    0.000000
# connective.tissue.disease                                    0    0.000000
# diabetes                                                     0    0.000000
# acute.renal.failure                                          0    0.000000
# moderate.to.severe.chronic.kidney.disease                    0    0.000000
# fio2                                                         0    0.000000
# oxygen.inhalation                                            0    0.000000
# respiratory.support.                                         0    0.000000
# movement                                                     0    0.000000
# verbal.response                                              0    0.000000
# eye.opening                                                  0    0.000000
# consciousness                                                0    0.000000
# type.II.respiratory.failure                                  0    0.000000
# CCI.score                                                    0    0.000000
# AIDS                                                         0    0.000000
# liver.disease                                                0    0.000000
# solid.tumor                                                  0    0.000000
# malignant.lymphoma                                           0    0.000000
# leukemia                                                     0    0.000000
# hemiplegia                                                   0    0.000000
# ageCat                                                       0    0.000000

# %%
df.drop(['high.sensitivity.protein','mitral.valve.EMS'],axis=1,inplace=True)

# %%
df.drop(['oxyhemoglobin','carboxyhemoglobin','methemoglobin','hematocrit.blood.gas','reduced.hemoglobin'],axis=1,inplace=True)

# %%
df.drop(['partial.pressure.of.carbon.dioxide','total.carbon.dioxide','potassium.ion','sodium.ion','measured.bicarbonate','free.calcium','partial.oxygen.pressure','oxygen.saturation','anion.gap','measured.residual.base','lactate','glucose.blood.gas'],axis=1,inplace=True)

# %%
df.drop(['fucosidase'],axis=1,inplace=True)

# %%
df.drop(['hydroxybutyrate.dehydrogenase','hydroxybutyrate.dehydrogenase.to.lactate.dehydrogenase','lactate.dehydrogenase','creatine.kinase.isoenzyme'],axis=1,inplace=True)

# %%
df.drop(['mean.platelet.volume'],axis=1,inplace=True)

# %%
df.drop(['glutamyltranspeptidase','albumin','alkaline.phosphatase','white.globulin.ratio','total.protein','total.bilirubin',
'direct.bilirubin',
'globulin',
'glutamic.pyruvic.transaminase',
'indirect.bilirubin'],axis=1,inplace=True)

# %%
df.drop(['international.normalized.ratio','activated.partial.thromboplastin.time','coefficient.of.variation.of.red.blood.cell.distribution.width','mean.hemoglobin.volume','mean.corpuscular.volume','neutrophil.ratio','mean.hemoglobin.concentration','eosinophil.ratio','basophil.ratio','monocyte.ratio','carbon.dioxide.binding.capacity'],axis=1,inplace=True)

# %%
import random

# %%
#df['mitral.valve.EMS'] = df['mitral.valve.EMS'].fillna(random.uniform(0.65,0.75))
#df['reduced.hemoglobin'] = df['reduced.hemoglobin'].fillna(random.uniform(0.5,4.5))
df['total.hemoglobin'] = df['total.hemoglobin'].fillna(random.uniform(135,170))
#df['oxyhemoglobin'] = df['oxyhemoglobin'].fillna(random.uniform(94.5,96.5))
#df['carboxyhemoglobin'] = df['carboxyhemoglobin'].fillna(random.uniform(0.1,1.5))
#df['methemoglobin'] = df['methemoglobin'].fillna(random.uniform(0.5,5.5))
#df['hematocrit.blood.gas'] = df['hematocrit.blood.gas'].fillna(random.uniform(0.,0.5))
df['chloride.ion'] = df['chloride.ion'].fillna(random.uniform(100,109))
df['pH'] = df['pH'].fillna(random.uniform(7.36,7.44))
df['standard.bicarbonate'] = df['standard.bicarbonate'].fillna(random.uniform(22,26.5))
#df['partial.pressure.of.carbon.dioxide'] = df['partial.pressure.of.carbon.dioxide'].fillna(random.uniform(36,44))
#df['total.carbon.dioxide'] = df['total.carbon.dioxide'].fillna(random.uniform(25,31))
#df['potassium.ion'] = df['potassium.ion'].fillna(random.uniform(3.6,4.4))
df['standard.residual.base'] = df['standard.residual.base'].fillna(random.uniform(-2.8,2.8))
#df['sodium.ion'] = df['sodium.ion'].fillna(random.uniform(136,146))
#df['free.calcium'] = df['free.calcium'].fillna(random.uniform(1.16,1.28))
#df['glucose.blood.gas'] = df['glucose.blood.gas'].fillna(random.uniform(4,6))
#df['lactate'] = df['lactate'].fillna(random.uniform(0.6,2.1))
#df['measured.residual.base'] = df['measured.residual.base'].fillna(random.uniform(-2.8,2.8))
#df['measured.bicarbonate'] = df['measured.bicarbonate'].fillna(random.uniform(23,29))
#df['oxygen.saturation'] = df['oxygen.saturation'].fillna(random.uniform(93.5,97.5))
#df['partial.oxygen.pressure'] = df['partial.oxygen.pressure'].fillna(random.uniform(83,108))
#df['anion.gap'] = df['anion.gap'].fillna(random.uniform(12,16))
df['left.ventricular.end.diastolic.diameter.LV'] = df['left.ventricular.end.diastolic.diameter.LV'].fillna(random.uniform(3.5,5.6))
#df['fucosidase'] = df['fucosidase'].fillna(random.uniform(0,40))
df['nucleotidase'] = df['nucleotidase'].fillna(random.uniform(0,10))
df['total.bile.acid'] = df['total.bile.acid'].fillna(random.uniform(0,20))
df['glutamic.oxaloacetic.transaminase'] = df['glutamic.oxaloacetic.transaminase'].fillna(random.uniform(15,40))
#df['hydroxybutyrate.dehydrogenase'] = df['hydroxybutyrate.dehydrogenase'].fillna(random.uniform(90,180))
df['creatine.kinase.isoenzyme.to.creatine.kinase'] = df['creatine.kinase.isoenzyme.to.creatine.kinase'].fillna(random.uniform(0,0.05))
df['creatine.kinase'] = df['creatine.kinase'].fillna(random.uniform(22,270))
#df['hydroxybutyrate.dehydrogenase.to.lactate.dehydrogenase'] = df['hydroxybutyrate.dehydrogenase.to.lactate.dehydrogenase'].fillna(random.uniform(0.2,0.8))
#df['lactate.dehydrogenase'] = df['lactate.dehydrogenase'].fillna(random.uniform(90,282))
#df['creatine.kinase.isoenzyme'] = df['creatine.kinase.isoenzyme'].fillna(random.uniform(0,32))
df['cholesterol'] = df['cholesterol'].fillna(random.uniform(2.9,5.68))
df['low.density.lipoprotein.cholesterol'] = df['low.density.lipoprotein.cholesterol'].fillna(random.uniform(0,3.36))
df['triglyceride'] = df['triglyceride'].fillna(random.uniform(0.2,2.26))
df['high.density.lipoprotein.cholesterol'] = df['high.density.lipoprotein.cholesterol'].fillna(random.uniform(0.9,2.19))
df['D.dimer'] = df['D.dimer'].fillna(random.uniform(0,0.55))
df['platelet.distribution.width'] = df['platelet.distribution.width'].fillna(random.uniform(9,17))
#df['mean.platelet.volume'] = df['mean.platelet.volume'].fillna(random.uniform(6.5,12))
df['platelet.hematocrit'] = df['platelet.hematocrit'].fillna(random.uniform(0.108,0.282))
#df['glutamyltranspeptidase'] = df['glutamyltranspeptidase'].fillna(random.uniform(10,60))
#df['albumin'] = df['albumin'].fillna(random.uniform(40,55))
#df['indirect.bilirubin'] = df['indirect.bilirubin'].fillna(random.uniform(0,16))
#df['white.globulin.ratio'] = df['white.globulin.ratio'].fillna(random.uniform(1.2,2.4))
#df['glutamic.pyruvic.transaminase'] = df['glutamic.pyruvic.transaminase'].fillna(random.uniform(9,50))
#df['total.protein'] = df['total.protein'].fillna(random.uniform(65,85))
#df['total.bilirubin'] = df['total.bilirubin'].fillna(random.uniform(2,20.4))
#df['direct.bilirubin'] = df['direct.bilirubin'].fillna(random.uniform(0,6.8))
#df['globulin'] = df['globulin'].fillna(random.uniform(20,40))
#df['alkaline.phosphatase'] = df['alkaline.phosphatase'].fillna(random.uniform(45,125))
df['high.sensitivity.troponin'] = df['high.sensitivity.troponin'].fillna(random.uniform(0,14))
df['glomerular.filtration.rate'] = df['glomerular.filtration.rate'].fillna(random.uniform(90,120))
df['prothrombin.activity'] = df['prothrombin.activity'].fillna(random.uniform(70,120))
df['cystatin'] = df['cystatin'].fillna(random.uniform(0.51,0.98))
df['brain.natriuretic.peptide'] = df['brain.natriuretic.peptide'].fillna(random.uniform(0,100))
# df['prothrombin.time.ratio'] = df['prothrombin.time.ratio'].fillna(random.uniform())
#df['international.normalized.ratio'] = df['international.normalized.ratio'].fillna(random.uniform(0.8,1.5))
df['thrombin.time'] = df['thrombin.time'].fillna(random.uniform(14,21))
df['fibrinogen'] = df['fibrinogen'].fillna(random.uniform(2,4))
#df['activated.partial.thromboplastin.time'] = df['activated.partial.thromboplastin.time'].fillna(random.uniform(20,40))
df['standard.deviation.of.red.blood.cell.distribution.width'] = df['standard.deviation.of.red.blood.cell.distribution.width'].fillna(random.uniform(40,53))
#df['coefficient.of.variation.of.red.blood.cell.distribution.width'] = df['coefficient.of.variation.of.red.blood.cell.distribution.width'].fillna(random.uniform(0,15))
#df['mean.hemoglobin.volume'] = df['mean.hemoglobin.volume'].fillna(random.uniform(27,35))
df['hemoglobin'] = df['hemoglobin'].fillna(random.uniform(110,160))
df['hematocrit'] = df['hematocrit'].fillna(random.uniform(35,50))
#df['mean.corpuscular.volume'] = df['mean.corpuscular.volume'].fillna(random.uniform(82,96))
#df['neutrophil.ratio'] = df['neutrophil.ratio'].fillna(random.uniform(0.5,0.7))
df['neutrophil.count'] = df['neutrophil.count'].fillna(random.uniform(2,7))
df['basophil.count'] = df['basophil.count'].fillna(random.uniform(0,0.1))
df['white.blood.cell'] = df['white.blood.cell'].fillna(random.uniform(4,10))
df['monocyte.count'] = df['monocyte.count'].fillna(random.uniform(0.2,0.8))
df['red.blood.cell'] = df['red.blood.cell'].fillna(random.uniform(3.5,5.5))
df['lymphocyte.count'] = df['lymphocyte.count'].fillna(random.uniform(0.8,4))
#df['mean.hemoglobin.concentration'] = df['mean.hemoglobin.concentration'].fillna(random.uniform(320,360))
df['platelet'] = df['platelet'].fillna(random.uniform(100,300))
#df['basophil.ratio'] = df['basophil.ratio'].fillna(random.uniform(0,1))
#df['eosinophil.ratio'] = df['eosinophil.ratio'].fillna(random.uniform(0.5,5))
#df['monocyte.ratio'] = df['monocyte.ratio'].fillna(random.uniform(3,11.4))
df['uric.acid'] = df['uric.acid'].fillna(random.uniform(150,440))
df['urea'] = df['urea'].fillna(random.uniform(1.7,8.3))
df['creatinine.enzymatic.method'] = df['creatinine.enzymatic.method'].fillna(random.uniform(44,110))
df['sodium'] = df['sodium'].fillna(random.uniform(137,147))
df['chloride'] = df['chloride'].fillna(random.uniform(99,110))
df['potassium'] = df['potassium'].fillna(random.uniform(3.5,4.5))
df['calcium'] = df['calcium'].fillna(random.uniform(2.11,2.52))
#df['carbon.dioxide.binding.capacity'] = df['carbon.dioxide.binding.capacity'].fillna(random.uniform(22,30))

# %%
df['eosinophil.count'] = df['eosinophil.count'].fillna(random.uniform(0.02,0.5))

# %%
null_count=df.isna().sum().sort_values(ascending=False)
percentage=((df.isna().sum()/df.isna().count())*100).sort_values(ascending=False)
null_df=pd.concat([null_count,percentage],axis=1,keys=["null_count","percentage"])
null_df
# Out:
#                                                     null_count  percentage
# body.temperature                                             0         0.0
# pulse                                                        0         0.0
# fibrinogen                                                   0         0.0
# prothrombin.activity                                         0         0.0
# thrombin.time                                                0         0.0
# D.dimer                                                      0         0.0
# neutrophil.count                                             0         0.0
# platelet.hematocrit                                          0         0.0
# platelet.distribution.width                                  0         0.0
# platelet                                                     0         0.0
# hemoglobin                                                   0         0.0
# eosinophil.count                                             0         0.0
# basophil.count                                               0         0.0
# lymphocyte.count                                             0         0.0
# hematocrit                                                   0         0.0
# standard.deviation.of.red.blood.cell.distributi...           0         0.0
# red.blood.cell                                               0         0.0
# monocyte.count                                               0         0.0
# white.blood.cell                                             0         0.0
# high.sensitivity.troponin                                    0         0.0
# calcium                                                      0         0.0
# potassium                                                    0         0.0
# low.density.lipoprotein.cholesterol                          0         0.0
# total.hemoglobin                                             0         0.0
# chloride.ion                                                 0         0.0
# standard.bicarbonate                                         0         0.0
# standard.residual.base                                       0         0.0
# pH                                                           0         0.0
# high.density.lipoprotein.cholesterol                         0         0.0
# triglyceride                                                 0         0.0
# cholesterol                                                  0         0.0
# chloride                                                     0         0.0
# total.bile.acid                                              0         0.0
# nucleotidase                                                 0         0.0
# brain.natriuretic.peptide                                    0         0.0
# creatine.kinase                                              0         0.0
# glutamic.oxaloacetic.transaminase                            0         0.0
# creatine.kinase.isoenzyme.to.creatine.kinase                 0         0.0
# sodium                                                       0         0.0
# cystatin                                                     0         0.0
# glomerular.filtration.rate                                   0         0.0
# uric.acid                                                    0         0.0
# myocardial.infarction                                        0         0.0
# peptic.ulcer.disease                                         0         0.0
# connective.tissue.disease                                    0         0.0
# Chronic.obstructive.pulmonary.disease                        0         0.0
# dementia                                                     0         0.0
# cerebrovascular.disease                                      0         0.0
# peripheral.vascular.disease                                  0         0.0
# congestive.heart.failure                                     0         0.0
# Killip.grade                                                 0         0.0
# moderate.to.severe.chronic.kidney.disease                    0         0.0
# NYHA.cardiac.function.classification                         0         0.0
# type.of.heart.failure                                        0         0.0
# BMI                                                          0         0.0
# map                                                          0         0.0
# diastolic.blood.pressure                                     0         0.0
# systolic.blood.pressure                                      0         0.0
# respiration                                                  0         0.0
# diabetes                                                     0         0.0
# hemiplegia                                                   0         0.0
# urea                                                         0         0.0
# verbal.response                                              0         0.0
# creatinine.enzymatic.method                                  0         0.0
# left.ventricular.end.diastolic.diameter.LV                   0         0.0
# acute.renal.failure                                          0         0.0
# fio2                                                         0         0.0
# oxygen.inhalation                                            0         0.0
# respiratory.support.                                         0         0.0
# movement                                                     0         0.0
# eye.opening                                                  0         0.0
# leukemia                                                     0         0.0
# consciousness                                                0         0.0
# type.II.respiratory.failure                                  0         0.0
# CCI.score                                                    0         0.0
# AIDS                                                         0         0.0
# liver.disease                                                0         0.0
# solid.tumor                                                  0         0.0
# malignant.lymphoma                                           0         0.0
# GCS                                                          0         0.0

# %%
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from keras.metrics import binary_accuracy
from tensorflow.keras.utils import to_categorical

# %%
#df['lactate.dehydrogenase'] = df['lactate.dehydrogenase'].fillna(random.uniform(90,282))
df5=df1[['map','cholesterol','high.density.lipoprotein.cholesterol','high.density.lipoprotein.cholesterol','triglyceride','high.sensitivity.protein','NYHA.cardiac.function.classification','red.blood.cell','white.blood.cell','platelet','hemoglobin']]

# %%
#df.drop(['gender','ageCat'],axis=1,inplace=True)

# %%
df4=df3['Atorvastatin calcium tablet']
#df4 = df4.to_frame()

# %%
df4.value_counts()
# Out:
# 0    1185
# 1     818
# Name: Atorvastatin calcium tablet, dtype: int64

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.RobustScaler()
robust_df = scaler.fit_transform(df5)

# %%
scaler = preprocessing.MinMaxScaler()
minmax_df = scaler.fit_transform(df5)

# %%
scaler = preprocessing.StandardScaler()
standard_df = scaler.fit_transform(df5)

# %%
y = to_categorical(df4)
y = np.vstack((y[:, 0]))

# %%
df.shape
# Out:
# (2003, 128)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df2, y, test_size=0.05)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# E:\anoconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
 
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[ 3 33]
#  [ 1 64]]

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
clf = make_pipeline(MinMaxScaler(),SVC(gamma='auto'))
clf.fit(X_train,y_train)
# Out:
# E:\anoconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Pipeline(steps=[('minmaxscaler', MinMaxScaler()), ('svc', SVC(gamma='auto'))])

# %%
clf.score(X_test,y_test)
# Out:
# 0.6138613861386139

# %%
clf = Sequential()
clf.add(Dense(16,activation='relu', input_dim=df5.shape[1]))
#clf.add(Dense(16,activation='relu'))
# clf.add(Dense(8,activation='relu'))
# clf.add(Dense(4,activation='relu'))
#clf.add(Dense(2,activation='sigmoid'))
clf.add(Dense(1, activation='sigmoid'))
clf.compile(loss='binary_crossentropy', optimizer="rmsprop", metrics=["accuracy"])
clf.fit(X_train, y_train,validation_data=(X_test,y_test),epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 2s 8ms/step - loss: 0.6805 - accuracy: 0.5852 - val_loss: 0.6640 - val_accuracy: 0.6436
# Epoch 2/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6781 - accuracy: 0.5878 - val_loss: 0.6611 - val_accuracy: 0.6436
# Epoch 3/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6775 - accuracy: 0.5878 - val_loss: 0.6588 - val_accuracy: 0.6436
# Epoch 4/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6770 - accuracy: 0.5878 - val_loss: 0.6577 - val_accuracy: 0.6436
# Epoch 5/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6765 - accuracy: 0.5883 - val_loss: 0.6592 - val_accuracy: 0.6436
# Epoch 6/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6759 - accuracy: 0.5883 - val_loss: 0.6573 - val_accuracy: 0.6436
# Epoch 7/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6758 - accuracy: 0.5883 - val_loss: 0.6573 - val_accuracy: 0.6436
# Epoch 8/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6753 - accuracy: 0.5883 - val_loss: 0.6557 - val_accuracy: 0.6436
# Epoch 9/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6744 - accuracy: 0.5878 - val_loss: 0.6540 - val_accuracy: 0.6436
# Epoch 10/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6750 - accuracy: 0.5883 - val_loss: 0.6553 - val_accuracy: 0.6436
# Epoch 11/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6745 - accuracy: 0.5883 - val_loss: 0.6570 - val_accuracy: 0.6535
# Epoch 12/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6741 - accuracy: 0.5889 - val_loss: 0.6544 - val_accuracy: 0.6436
# Epoch 13/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6740 - accuracy: 0.5883 - val_loss: 0.6564 - val_accuracy: 0.6436
# Epoch 14/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6737 - accuracy: 0.5889 - val_loss: 0.6565 - val_accuracy: 0.6535
# Epoch 15/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6736 - accuracy: 0.5889 - val_loss: 0.6553 - val_accuracy: 0.6436
# Epoch 16/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6731 - accuracy: 0.5883 - val_loss: 0.6543 - val_accuracy: 0.6436
# Epoch 17/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6730 - accuracy: 0.5883 - val_loss: 0.6545 - val_accuracy: 0.6535
# Epoch 18/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6729 - accuracy: 0.5894 - val_loss: 0.6556 - val_accuracy: 0.6535
# Epoch 19/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6726 - accuracy: 0.5899 - val_loss: 0.6546 - val_accuracy: 0.6535
# Epoch 20/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6723 - accuracy: 0.5894 - val_loss: 0.6534 - val_accuracy: 0.6535
# Epoch 21/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6722 - accuracy: 0.5894 - val_loss: 0.6531 - val_accuracy: 0.6535
# Epoch 22/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6720 - accuracy: 0.5899 - val_loss: 0.6534 - val_accuracy: 0.6535
# Epoch 23/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6717 - accuracy: 0.5904 - val_loss: 0.6520 - val_accuracy: 0.6535
# Epoch 24/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6717 - accuracy: 0.5889 - val_loss: 0.6540 - val_accuracy: 0.6535
# Epoch 25/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6714 - accuracy: 0.5899 - val_loss: 0.6537 - val_accuracy: 0.6535
# Epoch 26/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6712 - accuracy: 0.5925 - val_loss: 0.6526 - val_accuracy: 0.6535
# Epoch 27/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6711 - accuracy: 0.5915 - val_loss: 0.6518 - val_accuracy: 0.6535
# Epoch 28/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6708 - accuracy: 0.5931 - val_loss: 0.6548 - val_accuracy: 0.6535
# Epoch 29/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6708 - accuracy: 0.5936 - val_loss: 0.6543 - val_accuracy: 0.6436
# Epoch 30/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6707 - accuracy: 0.5931 - val_loss: 0.6537 - val_accuracy: 0.6436
# Epoch 31/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6704 - accuracy: 0.5920 - val_loss: 0.6523 - val_accuracy: 0.6535
# Epoch 32/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6704 - accuracy: 0.5946 - val_loss: 0.6543 - val_accuracy: 0.6436
# Epoch 33/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6703 - accuracy: 0.5925 - val_loss: 0.6531 - val_accuracy: 0.6436
# Epoch 34/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6700 - accuracy: 0.5925 - val_loss: 0.6516 - val_accuracy: 0.6436
# Epoch 35/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6700 - accuracy: 0.5957 - val_loss: 0.6511 - val_accuracy: 0.6436
# Epoch 36/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6699 - accuracy: 0.5957 - val_loss: 0.6509 - val_accuracy: 0.6436
# Epoch 37/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6697 - accuracy: 0.5952 - val_loss: 0.6519 - val_accuracy: 0.6337
# Epoch 38/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6695 - accuracy: 0.5941 - val_loss: 0.6528 - val_accuracy: 0.6337
# Epoch 39/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6695 - accuracy: 0.5962 - val_loss: 0.6521 - val_accuracy: 0.6337
# Epoch 40/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6694 - accuracy: 0.5936 - val_loss: 0.6519 - val_accuracy: 0.6337
# Epoch 41/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.6692 - accuracy: 0.5946 - val_loss: 0.6500 - val_accuracy: 0.6436
# Epoch 42/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.5931 - val_loss: 0.6488 - val_accuracy: 0.6436
# Epoch 43/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6689 - accuracy: 0.5915 - val_loss: 0.6484 - val_accuracy: 0.6436
# Epoch 44/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6690 - accuracy: 0.5925 - val_loss: 0.6505 - val_accuracy: 0.6337
# Epoch 45/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6688 - accuracy: 0.5925 - val_loss: 0.6498 - val_accuracy: 0.6337
# Epoch 46/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6685 - accuracy: 0.5936 - val_loss: 0.6535 - val_accuracy: 0.6337
# Epoch 47/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6683 - accuracy: 0.5952 - val_loss: 0.6548 - val_accuracy: 0.6040
# Epoch 48/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6688 - accuracy: 0.5941 - val_loss: 0.6509 - val_accuracy: 0.6337
# Epoch 49/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6684 - accuracy: 0.5957 - val_loss: 0.6506 - val_accuracy: 0.6337
# Epoch 50/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6683 - accuracy: 0.5941 - val_loss: 0.6496 - val_accuracy: 0.6337

# %%
clf.evaluate(X_test,y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6496 - accuracy: 0.6337
# [0.6496251225471497, 0.6336633563041687]

# %% [markdown]
# Some other trials

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, make_union
from sklearn.svm import LinearSVC
from tpot.builtins import StackingEstimator
from sklearn.impute import SimpleImputer
from tpot.export_utils import set_param_recursive
from sklearn.preprocessing import FunctionTransformer
from copy import copy

# %%
# NOTE: Make sure that the outcome column is labeled 'target' in the data file
tpot_data = minmax_df
features = tpot_data
training_features, testing_features, training_target, testing_target =train_test_split(features,df4, random_state=1)

# %%
exported_pipeline = make_pipeline(
    make_union(
        FunctionTransformer(copy),
        FunctionTransformer(copy)
    ),
    StackingEstimator(estimator=GradientBoostingClassifier(learning_rate=0.01, max_depth=1, max_features=0.7000000000000001, min_samples_leaf=19, min_samples_split=6, n_estimators=100, subsample=0.5)),
    StackingEstimator(estimator=LinearSVC(C=1.0, dual=False, loss="squared_hinge", penalty="l1", tol=0.0001)),
    ExtraTreesClassifier(bootstrap=True, criterion="gini", max_features=0.1, min_samples_leaf=18, min_samples_split=18, n_estimators=100)
)
# Fix random state for all the steps in exported pipeline
set_param_recursive(exported_pipeline.steps, 'random_state', 1)

exported_pipeline.fit(training_features, training_target)
results = exported_pipeline.predict(testing_features)
