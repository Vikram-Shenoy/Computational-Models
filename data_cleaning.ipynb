# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from sklearn.impute import KNNImputer

# %%
df = pd.read_csv('main_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  inpatient.number  gender  body.temperature     pulse  \
# 0           0            857781     1.0          0.242857  0.439394
# 1           1            743087     0.0          0.257143  0.479798
# 2           2            866418     1.0          0.214286  0.494949
# 3           3            775928     1.0          0.142857  0.368687
# 4           4            810128     0.0          0.000000  0.444444
#
#    respiration  systolic.blood.pressure  diastolic.blood.pressure       map  \
# 0     0.527778                 0.404762                  0.438356  0.422794
# 1     0.500000                 0.595238                  0.479452  0.533088
# 2     0.500000                 0.404762                  0.458904  0.433824
# 3     0.527778                 0.436508                  0.506849  0.474265
# 4     0.527778                 0.531746                  0.424658  0.474265
#
#         BMI  ...  carboxyhemoglobin  body.temperature.blood.gas  \
# ...

# %%
df = df.sort_values(by=['inpatient.number'], ascending=True)
df.reset_index(drop = True, inplace = True)
df.head()
#df.iloc[1700]
# Out:
#    Unnamed: 0  inpatient.number  gender  body.temperature     pulse  \
# 0        1057            722128     0.0          0.271429  0.333333
# 1         797            723327     0.0          0.142857  0.363636
# 2         296            723617     1.0          0.200000  0.353535
# 3        1372            724385     1.0          0.242857  0.651515
# 4         953            725509     0.0          0.271429  0.505051
#
#    respiration  systolic.blood.pressure  diastolic.blood.pressure       map  \
# 0     0.500000                 0.480159                  0.383562  0.428309
# 1     0.583333                 0.595238                  0.547945  0.569853
# 2     0.555556                 0.476190                  0.547945  0.514706
# 3     0.611111                 0.484127                  0.589041  0.540441
# 4     0.555556                 0.376984                  0.445205  0.413603
#
#         BMI  ...  carboxyhemoglobin  body.temperature.blood.gas  \
# ...

# %%
df.drop(['inpatient.number','Unnamed: 0','leukemia'],axis= 1,inplace=True)
df.head()
# Out:
#    gender  body.temperature     pulse  respiration  systolic.blood.pressure  \
# 0     0.0          0.271429  0.333333     0.500000                 0.480159
# 1     0.0          0.142857  0.363636     0.583333                 0.595238
# 2     1.0          0.200000  0.353535     0.555556                 0.476190
# 3     1.0          0.242857  0.651515     0.611111                 0.484127
# 4     0.0          0.271429  0.505051     0.555556                 0.376984
#
#    diastolic.blood.pressure       map       BMI  type.of.heart.failure  \
# 0                  0.383562  0.428309  0.046006                    1.0
# 1                  0.547945  0.569853  0.053564                    1.0
# 2                  0.547945  0.514706  0.076992                    1.0
# 3                  0.589041  0.540441  0.049828                    1.0
# 4                  0.445205  0.413603  0.054523                    1.0
#
#    NYHA.cardiac.function.classification  ...  carboxyhemoglobin  \
# ...

# %%
df.isna().any()
# Out:
# gender                     False
# body.temperature           False
# pulse                      False
# respiration                False
# systolic.blood.pressure    False
#                            ...
# anion.gap                   True
# free.calcium                True
# total.hemoglobin            True
# GCS                        False
# ageCat                     False
# Length: 145, dtype: bool

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
len(df.columns)
# Out:
# 145

# %%
x = list(df.isnull().sum(axis = 0))
# x, len(x) 
# len(x)

# %%
z = df.to_numpy(dtype=np.float64)

# %%
z.shape
# Out:
# (1996, 145)

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=18, weights='uniform', metric='nan_euclidean')

# %%
imputer.fit(z)
# Out:
# KNNImputer(n_neighbors=18)

# %%
xtrans = imputer.transform(z)

# %%
xtrans.shape
# Out:
# (1996, 144)

# %%
xtrans
# Out:
# array([[0.        , 0.27142857, 0.33333333, ..., 0.40873016, 1.        ,
#         0.66666667],
#        [0.        , 0.14285714, 0.36363636, ..., 0.22619048, 1.        ,
#         0.53333333],
#        [1.        , 0.2       , 0.35353535, ..., 0.41071429, 1.        ,
#         0.8       ],
#        ...,
#        [1.        , 0.21428571, 0.49494949, ..., 0.39880952, 1.        ,
#         0.8       ],
#        [1.        , 0.22857143, 0.54545455, ..., 0.51917989, 1.        ,
#         0.66666667],
#        [0.        , 0.21428571, 0.57070707, ..., 0.51818783, 1.        ,
#         1.        ]])

# %%
z[0][1]
# Out:
# 0.2714285714285712

# %%
df.columns
# Out:
# Index(['gender', 'body.temperature', 'pulse', 'respiration',
#        'systolic.blood.pressure', 'diastolic.blood.pressure', 'map', 'BMI',
#        'type.of.heart.failure', 'NYHA.cardiac.function.classification',
#        ...
#        'carboxyhemoglobin', 'body.temperature.blood.gas', 'oxygen.saturation',
#        'partial.oxygen.pressure', 'oxyhemoglobin', 'anion.gap', 'free.calcium',
#        'total.hemoglobin', 'GCS', 'ageCat'],
#       dtype='object', length=145)

# %%
# import math
# for i in range(145):
#     if math.isnan(z[0][i]):
#         continue
#     elif z[0][i] == xtrans[0][i]:
#         continue
#     elif z[0][i] != xtrans[0][i]:
#         print(i,z[0][i],xtrans[0][i])
#         break
# z[0][142],xtrans[0][142]

# %%
# for i in range(145):
#     if math.isnan(z[0][i]):
#         print(i,z[0][i],xtrans[0][i])

# %%
len(xtrans[0])
# Out:
# 144

# %%
# for i in range(145):
#         print(i,z[1700][i],xtrans[1700][i])

# %%
#df.drop(['body.temperature.blood.gas'],axis= 1,inplace=True)
df.head()
# Out:
#    gender  body.temperature     pulse  respiration  systolic.blood.pressure  \
# 0     0.0          0.271429  0.333333     0.500000                 0.480159
# 1     0.0          0.142857  0.363636     0.583333                 0.595238
# 2     1.0          0.200000  0.353535     0.555556                 0.476190
# 3     1.0          0.242857  0.651515     0.611111                 0.484127
# 4     0.0          0.271429  0.505051     0.555556                 0.376984
#
#    diastolic.blood.pressure       map       BMI  type.of.heart.failure  \
# 0                  0.383562  0.428309  0.046006                    1.0
# 1                  0.547945  0.569853  0.053564                    1.0
# 2                  0.547945  0.514706  0.076992                    1.0
# 3                  0.589041  0.540441  0.049828                    1.0
# 4                  0.445205  0.413603  0.054523                    1.0
#
#    NYHA.cardiac.function.classification  ...  measured.bicarbonate  \
# ...

# %%
df_trans = pd.DataFrame(xtrans, columns =df.columns)
df_trans.head()
# Out:
#    gender  body.temperature     pulse  respiration  systolic.blood.pressure  \
# 0     0.0          0.271429  0.333333     0.500000                 0.480159
# 1     0.0          0.142857  0.363636     0.583333                 0.595238
# 2     1.0          0.200000  0.353535     0.555556                 0.476190
# 3     1.0          0.242857  0.651515     0.611111                 0.484127
# 4     0.0          0.271429  0.505051     0.555556                 0.376984
#
#    diastolic.blood.pressure       map       BMI  type.of.heart.failure  \
# 0                  0.383562  0.428309  0.046006                    1.0
# 1                  0.547945  0.569853  0.053564                    1.0
# 2                  0.547945  0.514706  0.076992                    1.0
# 3                  0.589041  0.540441  0.049828                    1.0
# 4                  0.445205  0.413603  0.054523                    1.0
#
#    NYHA.cardiac.function.classification  ...  measured.bicarbonate  \
# ...

# %%
df_trans.to_csv('main_dataset_kNN.csv')
